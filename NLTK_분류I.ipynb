# %%
import nltk
from nltk.corpus import names
names.fileids()
# Out:
# ['female.txt', 'male.txt']

# %%
names.words('female.txt')[:5]
# Out:
# ['Abagael', 'Abagail', 'Abbe', 'Abbey', 'Abbi']

# %%
len(names.words("female.txt"))
# Out:
# 5001

# %%
names.words('male.txt')[:5]
# Out:
# ['Aamir', 'Aaron', 'Abbey', 'Abbie', 'Abbot']

# %%
len(names.words('male.txt'))
# Out:
# 2943

# %%
labeled_names = [(name,file.replace('.txt',''))
                for file in names.fileids()
                for name in names.words(file)]

# %%
print(sorted(labeled_names)[0:1000:30])
# Out:
# [('Aamir', 'male'), ('Ada', 'female'), ('Adolfo', 'male'), ('Agatha', 'female'), ('Ailina', 'female'), ('Albertine', 'female'), ('Alex', 'male'), ('Alicia', 'female'), ('Allison', 'female'), ('Alvina', 'female'), ('Amber', 'female'), ('Anallese', 'female'), ('Andriana', 'female'), ('Angie', 'male'), ('Annalisa', 'female'), ('Anson', 'male'), ('Aprilette', 'female'), ('Arel', 'male'), ('Arlyn', 'female'), ('Ashley', 'female'), ('Audrey', 'female'), ('Austin', 'male'), ('Babs', 'female'), ('Barnabas', 'male'), ('Bartlett', 'male'), ('Beck', 'male'), ('Bengt', 'male'), ('Berna', 'female'), ('Berti', 'female'), ('Bettye', 'female'), ('Bishop', 'male'), ('Bob', 'male'), ('Brande', 'female'), ('Brianna', 'female')]

# %%
import random
random.shuffle(labeled_names)

# %%
print(labeled_names[:20])
# Out:
# [('Dillon', 'male'), ('Aurel', 'female'), ('Connie', 'female'), ('Clem', 'male'), ('Slade', 'male'), ('Niccolo', 'male'), ('Ricky', 'male'), ('Ginnifer', 'female'), ('Ladonna', 'female'), ('Celestyna', 'female'), ('Maryanne', 'female'), ('Lindi', 'female'), ('Ware', 'male'), ('Wyatan', 'male'), ('Shandy', 'female'), ('Eddy', 'male'), ('Zabrina', 'female'), ('Odessa', 'female'), ('Matias', 'male'), ('Guthry', 'male')]

# %%
features = [({'last_letter':name[-1]},gender) for (name,gender) in labeled_names]
features[:5]
# Out:
# [({'last_letter': 'n'}, 'male'),
#  ({'last_letter': 'l'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'm'}, 'male'),
#  ({'last_letter': 'e'}, 'male')]

# %%
train_set, test_set = features[500:],features[:500]
classifier = nltk.NaiveBayesClassifier.train(train_set)

# %%
nltk.classify.accuracy(classifier,test_set)
# Out:
# 0.732

# %%
classifier.show_most_informative_features(10)
# Out:
# Most Informative Features
#              last_letter = 'a'            female : male   =     35.6 : 1.0
#              last_letter = 'k'              male : female =     30.7 : 1.0
#              last_letter = 'f'              male : female =     17.3 : 1.0
#              last_letter = 'p'              male : female =     11.2 : 1.0
#              last_letter = 'v'              male : female =      9.8 : 1.0
#              last_letter = 'd'              male : female =      9.5 : 1.0
#              last_letter = 'm'              male : female =      8.9 : 1.0
#              last_letter = 'o'              male : female =      8.3 : 1.0
#              last_letter = 'r'              male : female =      6.7 : 1.0
#              last_letter = 'g'              male : female =      6.3 : 1.0

# %%
classifier.classify({'last_letter':'a'})
# Out:
# 'female'

# %%
classifier.classify({'last_letter':'b'})
# Out:
# 'male'

# %%
classifier.classify({'last_letter':'c'})
# Out:
# 'male'

# %%
classifier.classify({'last_letter':'e'})
# Out:
# 'female'

# %%
labeled_names = [(name,file.replace('.txt','')) 
                 for file in names.fileids() for name in names.words(file)]

# %%
random.shuffle(labeled_names)

# %%
labeled_names
# Out:
# [('Daniel', 'female'),
#  ('Marie', 'female'),
#  ('Jephthah', 'male'),
#  ('Christen', 'female'),
#  ('Aimil', 'female'),
#  ('Kasey', 'female'),
#  ('Bernie', 'male'),
#  ('Karlotta', 'female'),
#  ('Penelope', 'female'),
#  ('Mabelle', 'female'),
#  ('Jorge', 'male'),
#  ('Dari', 'female'),
#  ('Kalli', 'female'),
#  ('Harman', 'male'),
#  ('Penni', 'female'),
#  ('Tim', 'female'),
#  ('Rebecka', 'female'),
#  ('Wallace', 'male'),
#  ('Gonzalo', 'male'),
#  ('Stella', 'female'),
#  ('Apostolos', 'male'),
#  ('Rubie', 'female'),
#  ('Ranice', 'female'),
#  ('Archy', 'male'),
#  ('Clarabelle', 'female'),
#  ('Ephrayim', 'male'),
#  ('Amelie', 'female'),
#  ('Bellanca', 'female'),
#  ('Orren', 'male'),
#  ('Isadora', 'female'),
#  ('Teodora', 'female'),
#  ('Ben', 'male'),
#  ('Anselma', 'female'),
#  ('Elaina', 'female'),
#  ('Willard', 'male'),
#  ('Moses', 'male'),
#  ('Norm', 'male'),
#  ('Belita', 'female'),
#  ('Thadeus', 'male'),
#  ('Demetre', 'male'),
#  ('Trey', 'male'),
#  ('Riane', 'female'),
#  ('Leigha', 'female'),
#  ('Emil', 'male'),
#  ('Jolyn', 'female'),
#  ('Anastasia', 'female'),
#  ('Kincaid', 'male'),
#  ('Price', 'male'),
#  ('Enrique', 'male'),
#  ('Quinn', 'female'),
#  ('Cissy', 'female'),
#  ('Bennie', 'female'),
#  ('Noach', 'male'),
#  ('Gabrielle', 'female'),
#  ('Elyssa', 'female'),
#  ('Rubia', 'female'),
#  ('Mikael', 'male'),
#  ('Star', 'female'),
#  ('Vail', 'male'),
#  ('Jamey', 'male'),
#  ('Juline', 'female'),
#  ('Clayborn', 'male'),
#  ('Zuzana', 'female'),
#  ('Jimmy', 'male'),
#  ('Teddy', 'female'),
#  ('Mirilla', 'female'),
#  ('Bethina', 'female'),
#  ('Barnabas', 'male'),
#  ('Tarra', 'female'),
#  ('Shira', 'female'),
#  ('Persis', 'female'),
#  ('Patrick', 'male'),
#  ('Katinka', 'female'),
#  ('Mohan', 'male'),
#  ('Ryann', 'female'),
#  ('Deva', 'female'),
#  ('Filipe', 'male'),
#  ('Thatcher', 'male'),
#  ('Sukey', 'female'),
#  ('Ettie', 'female'),
#  ('Gussy', 'female'),
#  ('Alfreda', 'female'),
#  ('Suzan', 'female'),
#  ('Lucien', 'male'),
#  ('Winnie', 'male'),
#  ('Clarence', 'male'),
#  ('Mickie', 'male'),
#  ('Natalia', 'female'),
#  ('Mercedes', 'female'),
#  ('Carena', 'female'),
#  ('Rock', 'male'),
#  ('Tad', 'male'),
#  ('Fabrianne', 'female'),
#  ('Hugh', 'male'),
#  ('Tiebold', 'male'),
#  ('Ernie', 'male'),
#  ('Rowena', 'female'),
#  ('Maryjo', 'female'),
#  ('Shamus', 'male'),
#  ('Lira', 'female'),
#  ('Silvia', 'female'),
#  ('Karsten', 'male'),
#  ('Winford', 'male'),
#  ('Everard', 'male'),
#  ('Parnell', 'male'),
#  ('Dalia', 'female'),
#  ('Fyodor', 'male'),
#  ('Yehudit', 'female'),
#  ('Onida', 'female'),
#  ('Dotty', 'female'),
#  ('Gerry', 'female'),
#  ('Aurea', 'female'),
#  ('Marline', 'female'),
#  ('Nerty', 'female'),
#  ('Neilla', 'female'),
#  ('Myrilla', 'female'),
#  ('Orrin', 'male'),
#  ('Gabi', 'female'),
#  ('Chantal', 'female'),
#  ('Roice', 'male'),
#  ('Janet', 'female'),
#  ('Olly', 'female'),
#  ('Hyacinthe', 'female'),
#  ('Gertrud', 'female'),
#  ('Daryl', 'male'),
#  ('Flora', 'female'),
#  ('Wendell', 'male'),
#  ('Salvador', 'male'),
#  ('Mahalia', 'female'),
#  ('Nanon', 'female'),
#  ('Margalit', 'female'),
#  ('Sayers', 'male'),
#  ('Ellis', 'male'),
#  ('Nevil', 'male'),
#  ('Quinn', 'male'),
#  ('Kimmie', 'female'),
#  ('Leigh', 'female'),
#  ('Garey', 'male'),
#  ('Gaven', 'male'),
#  ('Norman', 'male'),
#  ('Tatiana', 'female'),
#  ('Hillery', 'male'),
#  ('Justin', 'female'),
#  ('Garnette', 'female'),
#  ('Letisha', 'female'),
#  ('Bertha', 'female'),
#  ('Micheal', 'male'),
#  ('Drea', 'female'),
#  ('Betteanne', 'female'),
#  ('Parrnell', 'male'),
#  ('Carolin', 'female'),
#  ('Michaela', 'female'),
#  ('Grayce', 'female'),
#  ('Inge', 'female'),
#  ('Arden', 'female'),
#  ('Mustafa', 'male'),
#  ('Terina', 'female'),
#  ('Guido', 'male'),
#  ('Guinna', 'female'),
#  ('Emmet', 'male'),
#  ('Georgia', 'female'),
#  ('Sonia', 'female'),
#  ('Selena', 'female'),
#  ('Lorelle', 'female'),
#  ('Valida', 'female'),
#  ('Leeann', 'female'),
#  ('Lily', 'female'),
#  ('Geri', 'male'),
#  ('Inez', 'female'),
#  ('Rodrique', 'male'),
#  ('Barbaraanne', 'female'),
#  ('Emilio', 'male'),
#  ('Pinchas', 'male'),
#  ('Amara', 'female'),
#  ('Ken', 'male'),
#  ('Cassandra', 'female'),
#  ('Waverley', 'male'),
#  ('Lara', 'female'),
#  ('Kattie', 'female'),
#  ('Hector', 'male'),
#  ('Andrey', 'male'),
#  ('Chelsea', 'female'),
#  ('Rheba', 'female'),
#  ('Herminia', 'female'),
#  ('Windy', 'female'),
#  ('Umberto', 'male'),
#  ('Lucretia', 'female'),
#  ('Marya', 'female'),
#  ('Fifine', 'female'),
#  ('Katrina', 'female'),
#  ('Murphy', 'male'),
#  ('Loren', 'female'),
#  ('Duffy', 'male'),
#  ('Wolfgang', 'male'),
#  ('Sue-elle', 'female'),
#  ('Aileen', 'female'),
#  ('Lorne', 'female'),
#  ('Ramsay', 'male'),
#  ('Beryle', 'female'),
#  ('Derby', 'male'),
#  ('Stig', 'male'),
#  ('Alaa', 'male'),
#  ('Mela', 'female'),
#  ('Florence', 'female'),
#  ('Dominic', 'male'),
#  ('Jeremiah', 'male'),
#  ('Chrystal', 'female'),
#  ('Constance', 'female'),
#  ('Felicia', 'female'),
#  ('Opaline', 'female'),
#  ('Alec', 'male'),
#  ('Ivor', 'male'),
#  ('Renelle', 'female'),
#  ('Alfonse', 'male'),
#  ('Zeb', 'male'),
#  ('Guillaume', 'male'),
#  ('Carmelle', 'female'),
#  ('Emmaline', 'female'),
#  ('Allene', 'female'),
#  ('Juliette', 'female'),
#  ('Calla', 'female'),
#  ('Rudd', 'male'),
#  ('Callie', 'female'),
#  ('Tammie', 'female'),
#  ('Clarey', 'female'),
#  ('Sanders', 'male'),
#  ('Ann-Marie', 'female'),
#  ('Nydia', 'female'),
#  ('Timothy', 'male'),
#  ('Theada', 'female'),
#  ('Voltaire', 'male'),
#  ('Bernadette', 'female'),
#  ('Christy', 'female'),
#  ('Hymie', 'male'),
#  ('Josiah', 'male'),
#  ('Leontyne', 'female'),
#  ('Mariette', 'female'),
#  ('Lil', 'female'),
#  ('Lamb', 'female'),
#  ('Esma', 'female'),
#  ('Lynette', 'female'),
#  ('Bill', 'female'),
#  ('Friedric', 'male'),
#  ('Angel', 'female'),
#  ('Frayda', 'female'),
#  ('Flore', 'female'),
#  ('Jody', 'female'),
#  ('Nikkie', 'female'),
#  ('Krissy', 'female'),
#  ('Bradly', 'male'),
#  ('Antonie', 'female'),
#  ('Sisely', 'female'),
#  ('Wynnie', 'female'),
#  ('Valene', 'female'),
#  ('Jandy', 'female'),
#  ('Josee', 'female'),
#  ('Meira', 'female'),
#  ('Kellie', 'female'),
#  ('Kari', 'female'),
#  ('Cooper', 'male'),
#  ('Ash', 'male'),
#  ('Sigfried', 'male'),
#  ('Quinton', 'male'),
#  ('Spencer', 'male'),
#  ('Malissia', 'female'),
#  ('Beowulf', 'male'),
#  ('Henry', 'male'),
#  ('Cody', 'male'),
#  ('Neille', 'female'),
#  ('Nanette', 'female'),
#  ('Olia', 'female'),
#  ('Marti', 'female'),
#  ('Karin', 'female'),
#  ('Ruth', 'female'),
#  ('Zacharie', 'male'),
#  ('Stanley', 'male'),
#  ('Jean', 'male'),
#  ('Dominick', 'male'),
#  ('Giovanni', 'male'),
#  ('Tommie', 'female'),
#  ('Istvan', 'male'),
#  ('Harmonie', 'female'),
#  ('Vikky', 'female'),
#  ('Douglass', 'male'),
#  ('Ilyssa', 'female'),
#  ('Laurette', 'female'),
#  ('Janot', 'female'),
#  ('Dina', 'female'),
#  ('Gaynor', 'female'),
#  ('Gita', 'female'),
#  ('Hillary', 'female'),
#  ('Lancelot', 'male'),
#  ('Inci', 'female'),
#  ('Ariana', 'female'),
#  ('Elli', 'female'),
#  ('Elbert', 'male'),
#  ('Wolfram', 'male'),
#  ('Tamarra', 'female'),
#  ('Adlai', 'male'),
#  ('Magnus', 'male'),
#  ('Candida', 'female'),
#  ('Trish', 'female'),
#  ('Pauli', 'female'),
#  ('Arther', 'male'),
#  ('Niven', 'male'),
#  ('Alonzo', 'male'),
#  ('Katy', 'female'),
#  ('June', 'female'),
#  ('Zelda', 'female'),
#  ('Dudley', 'male'),
#  ('Kane', 'male'),
#  ('Cecil', 'male'),
#  ('Clarance', 'male'),
#  ('Rhona', 'female'),
#  ('Emlyn', 'female'),
#  ('Seth', 'male'),
#  ('Jordanna', 'female'),
#  ('Eartha', 'female'),
#  ('Rosalia', 'female'),
#  ('Lauretta', 'female'),
#  ('Emelina', 'female'),
#  ('Anet', 'female'),
#  ('Rad', 'male'),
#  ('Vally', 'female'),
#  ('Ole', 'male'),
#  ('Estrella', 'female'),
#  ('Marguerite', 'female'),
#  ('Casandra', 'female'),
#  ('Wilie', 'female'),
#  ('Nickolas', 'male'),
#  ('Kakalina', 'female'),
#  ('Kamillah', 'female'),
#  ('Adriana', 'female'),
#  ('Brewer', 'male'),
#  ('Una', 'female'),
#  ('Arline', 'female'),
#  ('Juanita', 'female'),
#  ('Graehme', 'male'),
#  ('Tuesday', 'female'),
#  ('Benita', 'female'),
#  ('Fiona', 'female'),
#  ('Zoe', 'female'),
#  ('Ariel', 'male'),
#  ('Barty', 'male'),
#  ('Alexia', 'female'),
#  ('Coralie', 'female'),
#  ('Davie', 'male'),
#  ('Dallas', 'male'),
#  ('Scarlett', 'female'),
#  ('Phillipp', 'male'),
#  ('Gill', 'male'),
#  ('Caron', 'female'),
#  ('Lynelle', 'female'),
#  ('Englebart', 'male'),
#  ('Mignon', 'female'),
#  ('Petronilla', 'female'),
#  ('Odilia', 'female'),
#  ('Zara', 'female'),
#  ('Jessie', 'male'),
#  ('Berni', 'female'),
#  ('Jo', 'female'),
#  ('Pierson', 'male'),
#  ('Brandy', 'male'),
#  ('Vernon', 'male'),
#  ('Eadith', 'female'),
#  ('Cherye', 'female'),
#  ('Alia', 'female'),
#  ('Kary', 'female'),
#  ('Idell', 'female'),
#  ('Karia', 'female'),
#  ('Perry', 'male'),
#  ('Lilian', 'female'),
#  ('Honor', 'female'),
#  ('Belinda', 'female'),
#  ('Solomon', 'male'),
#  ('Joey', 'male'),
#  ('Berthe', 'female'),
#  ('Fan', 'female'),
#  ('Hermann', 'male'),
#  ('Yaakov', 'male'),
#  ('Kelvin', 'male'),
#  ('Dafna', 'female'),
#  ('Milli', 'female'),
#  ('Gonzales', 'male'),
#  ('Florice', 'female'),
#  ('Camilla', 'female'),
#  ('Ximenes', 'male'),
#  ('Sonnnie', 'female'),
#  ('Arlina', 'female'),
#  ('Salomone', 'male'),
#  ('Kirstie', 'female'),
#  ('Durward', 'male'),
#  ('Cathy', 'female'),
#  ('Kessiah', 'female'),
#  ('Tarrance', 'male'),
#  ('Lynnet', 'female'),
#  ('Matteo', 'male'),
#  ('Horacio', 'male'),
#  ('Timotheus', 'male'),
#  ('Richardo', 'male'),
#  ('Zahara', 'female'),
#  ('Winthrop', 'male'),
#  ('Sabina', 'female'),
#  ('Emelda', 'female'),
#  ('Jocelin', 'female'),
#  ('Thaine', 'male'),
#  ('Keenan', 'male'),
#  ('Natasha', 'female'),
#  ('Cole', 'male'),
#  ('Debbi', 'female'),
#  ('Andonis', 'male'),
#  ('Tyrus', 'male'),
#  ('Russel', 'male'),
#  ('Ronny', 'female'),
#  ('Jolynn', 'female'),
#  ('Jose', 'male'),
#  ('Reggy', 'male'),
#  ('Ludwig', 'male'),
#  ('Vilhelm', 'male'),
#  ('Robenia', 'female'),
#  ('Mirelle', 'female'),
#  ('Dwain', 'male'),
#  ('Winslow', 'male'),
#  ('Else', 'female'),
#  ('Lyn', 'male'),
#  ('Royal', 'male'),
#  ('Regan', 'female'),
#  ('Kurt', 'male'),
#  ('Dorey', 'female'),
#  ('Dela', 'female'),
#  ('Roshelle', 'female'),
#  ('Anders', 'male'),
#  ('Ninon', 'female'),
#  ('Alidia', 'female'),
#  ('Marcia', 'female'),
#  ('Christie', 'male'),
#  ('Marylynne', 'female'),
#  ('Benni', 'female'),
#  ('Barbra', 'female'),
#  ('Vick', 'male'),
#  ('Woodman', 'male'),
#  ('Bunni', 'female'),
#  ('Suki', 'female'),
#  ('Renee', 'female'),
#  ('Zeke', 'male'),
#  ('Theressa', 'female'),
#  ('Sammie', 'male'),
#  ('Pat', 'female'),
#  ('Ivory', 'female'),
#  ('Joel', 'male'),
#  ('Welsh', 'male'),
#  ('Burke', 'male'),
#  ('Lark', 'female'),
#  ('Catherina', 'female'),
#  ('Wandie', 'female'),
#  ('Gipsy', 'female'),
#  ('Nissy', 'female'),
#  ('Shepherd', 'male'),
#  ('Sax', 'male'),
#  ('Fanni', 'female'),
#  ('Darcey', 'female'),
#  ('Judith', 'female'),
#  ('Roselin', 'female'),
#  ('Luciano', 'male'),
#  ('Gretchen', 'male'),
#  ('Querida', 'female'),
#  ('Heather', 'female'),
#  ('Elden', 'male'),
#  ('Xenia', 'female'),
#  ('Liz', 'female'),
#  ('Brandi', 'female'),
#  ('Arianne', 'female'),
#  ('Devan', 'female'),
#  ('Adger', 'male'),
#  ('Devin', 'female'),
#  ('Jimmie', 'male'),
#  ('Kippie', 'female'),
#  ('Rosemaria', 'female'),
#  ('Devon', 'male'),
#  ('Kimball', 'male'),
#  ('Halie', 'female'),
#  ('Laura', 'female'),
#  ('Joana', 'female'),
#  ('Yacov', 'male'),
#  ('Guillema', 'female'),
#  ('Ingram', 'male'),
#  ('Ajai', 'male'),
#  ('Harold', 'male'),
#  ('Raquel', 'female'),
#  ('Daryl', 'female'),
#  ('Neddie', 'male'),
#  ('Valry', 'female'),
#  ('Vitia', 'female'),
#  ('Pooh', 'male'),
#  ('Erastus', 'male'),
#  ('Joellyn', 'female'),
#  ('Benoite', 'female'),
#  ('Merlina', 'female'),
#  ('Sheeree', 'female'),
#  ('Izabel', 'female'),
#  ('Rea', 'female'),
#  ('Ajay', 'male'),
#  ('Corina', 'female'),
#  ('Noelyn', 'female'),
#  ('Hasheem', 'male'),
#  ('Concordia', 'female'),
#  ('Marylin', 'female'),
#  ('Elie', 'female'),
#  ('Iona', 'female'),
#  ('Allin', 'male'),
#  ('Verne', 'male'),
#  ('Bertie', 'female'),
#  ('Tann', 'male'),
#  ('Dane', 'male'),
#  ('Trixi', 'female'),
#  ('Hertha', 'female'),
#  ('Jillayne', 'female'),
#  ('Paolo', 'male'),
#  ('Madelon', 'female'),
#  ('Deedee', 'female'),
#  ('Harmon', 'male'),
#  ('Elwin', 'male'),
#  ('Kaia', 'female'),
#  ('Joete', 'female'),
#  ('Claude', 'male'),
#  ('Xylina', 'female'),
#  ('Brigitte', 'female'),
#  ('Claus', 'male'),
#  ('Catrina', 'female'),
#  ('Ilona', 'female'),
#  ('Gus', 'male'),
#  ('Gerda', 'female'),
#  ('Dyann', 'female'),
#  ('Muffin', 'male'),
#  ('Blanch', 'female'),
#  ('Penny', 'female'),
#  ('Saudra', 'female'),
#  ('Myrtia', 'female'),
#  ('Elsy', 'female'),
#  ('Fran', 'female'),
#  ('Amalia', 'female'),
#  ('Goldi', 'female'),
#  ('Malissa', 'female'),
#  ('Karee', 'female'),
#  ('Thia', 'female'),
#  ('Viva', 'female'),
#  ('Gregg', 'male'),
#  ('Harmonia', 'female'),
#  ('Toinette', 'female'),
#  ('Harry', 'male'),
#  ('Josie', 'female'),
#  ('Juana', 'female'),
#  ('Merna', 'female'),
#  ('Mella', 'female'),
#  ('Franky', 'male'),
#  ('Yvette', 'female'),
#  ('Arielle', 'female'),
#  ('Myrle', 'female'),
#  ('Terence', 'male'),
#  ('Gwenora', 'female'),
#  ('Myrlene', 'female'),
#  ('Sheelah', 'female'),
#  ('Walden', 'male'),
#  ('Lotte', 'female'),
#  ('Sorcha', 'female'),
#  ('Judy', 'male'),
#  ('Teddie', 'female'),
#  ('Thad', 'male'),
#  ('Gilberta', 'female'),
#  ('Onlea', 'female'),
#  ('Nelle', 'female'),
#  ('Atlante', 'female'),
#  ('Ferdinand', 'male'),
#  ('Terri', 'female'),
#  ('Corbin', 'male'),
#  ('Shepard', 'male'),
#  ('Shannon', 'female'),
#  ('Ardith', 'female'),
#  ('Selie', 'female'),
#  ('Laird', 'male'),
#  ('Benito', 'male'),
#  ('Gale', 'male'),
#  ('Maxie', 'female'),
#  ('Robinia', 'female'),
#  ('Jemmy', 'female'),
#  ('Karleen', 'female'),
#  ('Tera', 'female'),
#  ('Willy', 'female'),
#  ('Marlie', 'female'),
#  ('Carlotta', 'female'),
#  ('Myriam', 'female'),
#  ('Kailey', 'female'),
#  ('Tarrah', 'female'),
#  ('Faye', 'female'),
#  ('Reiko', 'female'),
#  ('Tobi', 'female'),
#  ('Kassia', 'female'),
#  ('Rahul', 'male'),
#  ('Jilli', 'female'),
#  ('Arda', 'female'),
#  ('Ofella', 'female'),
#  ('Caritta', 'female'),
#  ('Gale', 'female'),
#  ('Gill', 'female'),
#  ('Finley', 'male'),
#  ('Theresa-Marie', 'female'),
#  ('Ignaz', 'male'),
#  ('Rodolphe', 'male'),
#  ('Biff', 'male'),
#  ('Halli', 'female'),
#  ('Millie', 'female'),
#  ('Debby', 'female'),
#  ('Steward', 'male'),
#  ('Ki', 'female'),
#  ('Cherie', 'female'),
#  ('Hannie', 'female'),
#  ('Elsi', 'female'),
#  ('Devina', 'female'),
#  ('Gabriellia', 'female'),
#  ('Mora', 'female'),
#  ('Hewe', 'male'),
#  ('Halette', 'female'),
#  ('Allison', 'female'),
#  ('Carmine', 'male'),
#  ('Kipp', 'female'),
#  ('Dido', 'female'),
#  ('Sheryl', 'female'),
#  ('Jerri', 'male'),
#  ('Ianthe', 'female'),
#  ('Adel', 'female'),
#  ('Leticia', 'female'),
#  ('Klara', 'female'),
#  ('Constantine', 'male'),
#  ('Alyce', 'female'),
#  ('Siobhan', 'female'),
#  ('Benedict', 'male'),
#  ('Agna', 'female'),
#  ('Douggie', 'male'),
#  ('Marley', 'female'),
#  ('Darian', 'male'),
#  ('Darrin', 'male'),
#  ('Eddy', 'male'),
#  ('Erich', 'male'),
#  ('Wadsworth', 'male'),
#  ('Flint', 'male'),
#  ('Gabriela', 'female'),
#  ('Arlena', 'female'),
#  ('Emmalynne', 'female'),
#  ('Timmy', 'female'),
#  ('Blondelle', 'female'),
#  ('Rodger', 'male'),
#  ('Berenice', 'female'),
#  ('Aveline', 'female'),
#  ('Louie', 'male'),
#  ('Reg', 'male'),
#  ('Nora', 'female'),
#  ('Sabra', 'female'),
#  ('Sioux', 'female'),
#  ('Krishna', 'male'),
#  ('Christophe', 'male'),
#  ('Adam', 'male'),
#  ('Marcelia', 'female'),
#  ('Marsiella', 'female'),
#  ('Sib', 'female'),
#  ('Trace', 'female'),
#  ('Kristien', 'female'),
#  ('Mohamed', 'male'),
#  ('Jonas', 'male'),
#  ('Mariska', 'female'),
#  ('Caril', 'female'),
#  ('Annmarie', 'female'),
#  ('Kittie', 'female'),
#  ('Westleigh', 'male'),
#  ('Lilia', 'female'),
#  ('Andree', 'female'),
#  ('Carlen', 'female'),
#  ('Trevor', 'male'),
#  ('Jermain', 'male'),
#  ('Ernesto', 'male'),
#  ('Jeanine', 'female'),
#  ('Shani', 'female'),
#  ('Risa', 'female'),
#  ('Ephram', 'male'),
#  ('Roderich', 'male'),
#  ('Magdalene', 'female'),
#  ('Audrie', 'female'),
#  ('Joselyn', 'female'),
#  ('Cass', 'male'),
#  ('Joice', 'female'),
#  ('Imojean', 'female'),
#  ('Meggi', 'female'),
#  ('Jaine', 'female'),
#  ('Abdul', 'male'),
#  ('Darci', 'female'),
#  ('Adaline', 'female'),
#  ('Erena', 'female'),
#  ('Letti', 'female'),
#  ('Verene', 'female'),
#  ('Dion', 'male'),
#  ('Northrop', 'male'),
#  ('Wendeline', 'female'),
#  ('Anny', 'female'),
#  ('Rakel', 'female'),
#  ('Rozanna', 'female'),
#  ('Shandy', 'female'),
#  ('Michal', 'female'),
#  ('Remington', 'male'),
#  ('Nada', 'female'),
#  ('Angelita', 'female'),
#  ('Alecia', 'female'),
#  ('Kermit', 'male'),
#  ('Sacha', 'female'),
#  ('Jefry', 'male'),
#  ('Jonathan', 'male'),
#  ('Fredra', 'female'),
#  ('Kalle', 'male'),
#  ('Kerrin', 'female'),
#  ('Catherin', 'female'),
#  ('Siddhartha', 'male'),
#  ('Raine', 'female'),
#  ('Bjorne', 'male'),
#  ('Cameron', 'male'),
#  ('Raimund', 'male'),
#  ('Ninetta', 'female'),
#  ('Troy', 'male'),
#  ('Carlisle', 'female'),
#  ('Wait', 'male'),
#  ('Pincus', 'male'),
#  ('Francesco', 'male'),
#  ('Oscar', 'male'),
#  ('Grady', 'male'),
#  ('Whitman', 'male'),
#  ('Starlene', 'female'),
#  ('Tommy', 'female'),
#  ('Perla', 'female'),
#  ('Deny', 'female'),
#  ('Carolyn', 'female'),
#  ('Kaari', 'female'),
#  ('Aristotle', 'male'),
#  ('Shell', 'male'),
#  ('Justine', 'female'),
#  ('Andres', 'male'),
#  ('Delinda', 'female'),
#  ('Greg', 'male'),
#  ('Lou', 'male'),
#  ('Ellsworth', 'male'),
#  ('Gera', 'female'),
#  ('Trula', 'female'),
#  ('Ellene', 'female'),
#  ('Joelle', 'female'),
#  ('Barrie', 'male'),
#  ('Lurlene', 'female'),
#  ('Toddy', 'male'),
#  ('Wood', 'male'),
#  ('Linet', 'female'),
#  ('Tobias', 'male'),
#  ('Maiga', 'female'),
#  ('Katharine', 'female'),
#  ('Heida', 'female'),
#  ('Jean-Paul', 'male'),
#  ('Kata', 'female'),
#  ('Alyssa', 'female'),
#  ('Stew', 'male'),
#  ('Kori', 'female'),
#  ('Lorinda', 'female'),
#  ('Heywood', 'male'),
#  ('Simonette', 'female'),
#  ('Carlee', 'female'),
#  ('Urbanus', 'male'),
#  ('Torrey', 'male'),
#  ('Sasha', 'female'),
#  ('Luke', 'male'),
#  ('Joane', 'female'),
#  ('Grete', 'female'),
#  ('Laurance', 'male'),
#  ('Dannie', 'male'),
#  ('Alfonso', 'male'),
#  ('Dewitt', 'male'),
#  ('Major', 'male'),
#  ('Julianne', 'female'),
#  ('Kalindi', 'female'),
#  ('Roseanna', 'female'),
#  ('Moria', 'female'),
#  ('Chickie', 'female'),
#  ('Irina', 'female'),
#  ('Ardath', 'female'),
#  ('Alan', 'male'),
#  ('Rochelle', 'female'),
#  ('Hanna', 'female'),
#  ('Cherin', 'female'),
#  ('Lena', 'female'),
#  ('Kathryne', 'female'),
#  ('Conney', 'female'),
#  ('Weidar', 'male'),
#  ('Lorilyn', 'female'),
#  ('Sinead', 'female'),
#  ('Freddie', 'female'),
#  ('Hali', 'female'),
#  ('Bertie', 'male'),
#  ('Andrea', 'male'),
#  ('Frank', 'female'),
#  ('Virgie', 'female'),
#  ('Dawson', 'male'),
#  ('Legra', 'female'),
#  ('Dorri', 'female'),
#  ('Gloriana', 'female'),
#  ('Verena', 'female'),
#  ('Constancia', 'female'),
#  ('Elroy', 'male'),
#  ('Margi', 'female'),
#  ('Barnie', 'male'),
#  ('Lawson', 'male'),
#  ('Cristabel', 'female'),
#  ('Terese', 'female'),
#  ('Fredrika', 'female'),
#  ('Suzanne', 'female'),
#  ('Lolande', 'female'),
#  ('Jerry', 'female'),
#  ('Dasha', 'female'),
#  ('Kris', 'male'),
#  ('Marius', 'male'),
#  ('Penelopa', 'female'),
#  ('Carlo', 'male'),
#  ('Luis', 'male'),
#  ('Elsbeth', 'female'),
#  ('Agneta', 'female'),
#  ('Leora', 'female'),
#  ('Esau', 'male'),
#  ('Gideon', 'male'),
#  ('Carlos', 'male'),
#  ('Dawn', 'female'),
#  ('Regan', 'male'),
#  ('Valentina', 'female'),
#  ('Nessie', 'female'),
#  ('Bride', 'female'),
#  ('Magda', 'female'),
#  ('Christa', 'female'),
#  ('Jordon', 'male'),
#  ('Nataline', 'female'),
#  ('Anne-Corinne', 'female'),
#  ('Dorolisa', 'female'),
#  ('Audre', 'female'),
#  ('Merline', 'female'),
#  ('Fawna', 'female'),
#  ('Sarette', 'female'),
#  ('Zorah', 'female'),
#  ('Juditha', 'female'),
#  ('Agretha', 'female'),
#  ('Neila', 'female'),
#  ('Sean', 'female'),
#  ('Aurelia', 'female'),
#  ('Logan', 'male'),
#  ('Jazmin', 'female'),
#  ('Walter', 'male'),
#  ('Bartholemy', 'male'),
#  ('Maximilian', 'male'),
#  ('Doretta', 'female'),
#  ('Lowell', 'male'),
#  ('Flemming', 'male'),
#  ('Kylen', 'female'),
#  ('Ashlen', 'female'),
#  ('Vida', 'female'),
#  ('Jaime', 'female'),
#  ('Sallee', 'female'),
#  ('Lona', 'female'),
#  ('Ariela', 'female'),
#  ('Rodi', 'female'),
#  ('Riccardo', 'male'),
#  ('Chriss', 'female'),
#  ('Alanah', 'female'),
#  ('Gus', 'female'),
#  ('Sibley', 'female'),
#  ('Simone', 'male'),
#  ('Vivien', 'female'),
#  ('Phillida', 'female'),
#  ('Nanci', 'female'),
#  ('Golda', 'female'),
#  ('Cristi', 'female'),
#  ('Jarvis', 'male'),
#  ('Monty', 'male'),
#  ('Kaleena', 'female'),
#  ('Annmaria', 'female'),
#  ('Alfonzo', 'male'),
#  ('Pansy', 'female'),
#  ('Jud', 'male'),
#  ('Lib', 'female'),
#  ('Alaine', 'female'),
#  ('Anabella', 'female'),
#  ('Didi', 'female'),
#  ('Noemi', 'female'),
#  ('Quent', 'male'),
#  ('Martyn', 'male'),
#  ('Candra', 'female'),
#  ('Rosalinda', 'female'),
#  ('Renate', 'female'),
#  ('Xever', 'male'),
#  ('Kylynn', 'female'),
#  ('Kassey', 'female'),
#  ('Berget', 'female'),
#  ('Virginia', 'female'),
#  ('Felisha', 'female'),
#  ('Raynor', 'male'),
#  ('Essy', 'female'),
#  ('Woody', 'male'),
#  ('Wilburn', 'male'),
#  ('Glori', 'female'),
#  ('Niall', 'male'),
#  ('Keil', 'male'),
#  ('Marja', 'female'),
#  ('Berti', 'female'),
#  ('Theresa', 'female'),
#  ('Collin', 'male'),
#  ('Marty', 'female'),
#  ('Barby', 'female'),
#  ('Keeley', 'female'),
#  ('Donn', 'male'),
#  ('Orson', 'male'),
#  ('Ainslie', 'female'),
#  ('Florentia', 'female'),
#  ('Aridatha', 'female'),
#  ('Edmund', 'male'),
#  ('Delcina', 'female'),
#  ('Alix', 'male'),
#  ('Tabor', 'male'),
#  ('Dunc', 'male'),
#  ('Danna', 'female'),
#  ('Babs', 'female'),
#  ('Evangelin', 'female'),
#  ('Crawford', 'male'),
#  ('Reta', 'female'),
#  ('Austin', 'female'),
#  ('Jori', 'female'),
#  ('Nadya', 'female'),
#  ('Elicia', 'female'),
#  ('Brunella', 'female'),
#  ('Jacquetta', 'female'),
#  ('Clem', 'female'),
#  ('Dinny', 'female'),
#  ('Lucas', 'male'),
#  ('Garfinkel', 'male'),
#  ('Carina', 'female'),
#  ('Morly', 'male'),
#  ('Konstantin', 'male'),
#  ('Yetty', 'female'),
#  ('Shawna', 'female'),
#  ('Salim', 'male'),
#  ('Tanney', 'male'),
#  ('Stewart', 'male'),
#  ('Coralyn', 'female'),
#  ('Piper', 'female'),
#  ('Storey', 'female'),
#  ('Doralia', 'female'),
#  ('Evvie', 'female'),
#  ('Betta', 'female'),
#  ('Rebekkah', 'female'),
#  ('Chris', 'female'),
#  ('Talbot', 'male'),
#  ('Cristionna', 'female'),
#  ('Millicent', 'male'),
#  ('Joaquin', 'male'),
#  ('Marianna', 'female'),
#  ('Cindie', 'female'),
#  ('Merrill', 'female'),
#  ('Elvera', 'female'),
#  ('Bidget', 'female'),
#  ('Claudelle', 'female'),
#  ('Hetty', 'female'),
#  ('Lysandra', 'female'),
#  ('Ariella', 'female'),
#  ('Timi', 'female'),
#  ('Willy', 'male'),
#  ('Shelagh', 'female'),
#  ('Davin', 'male'),
#  ('Mag', 'female'),
#  ('Libbie', 'female'),
#  ('Cal', 'female'),
#  ('Gayleen', 'female'),
#  ('Finn', 'male'),
#  ('Callida', 'female'),
#  ('Etta', 'female'),
#  ('Ania', 'female'),
#  ('Geraldina', 'female'),
#  ('Bob', 'male'),
#  ('Inigo', 'male'),
#  ('Phillipe', 'male'),
#  ('Angelina', 'female'),
#  ('Nerissa', 'female'),
#  ('Vena', 'female'),
#  ('Henrieta', 'female'),
#  ('Elysee', 'female'),
#  ('Regine', 'female'),
#  ('Evonne', 'female'),
#  ('Gillie', 'female'),
#  ('Catarina', 'female'),
#  ('Ninnette', 'female'),
#  ('Milena', 'female'),
#  ('Nannette', 'female'),
#  ('Sheridan', 'male'),
#  ('Dahlia', 'female'),
#  ('Tomi', 'female'),
#  ...]
