# %%
import nltk
from nltk import book
# Out:
# *** Introductory Examples for the NLTK Book ***
# Loading text1, ..., text9 and sent1, ..., sent9
# Type the name of the text or sentence to view it.
# Type: 'texts()' or 'sents()' to list the materials.
# text1: Moby Dick by Herman Melville 1851
# text2: Sense and Sensibility by Jane Austen 1811
# text3: The Book of Genesis
# text4: Inaugural Address Corpus
# text5: Chat Corpus
# text6: Monty Python and the Holy Grail
# text7: Wall Street Journal
# text8: Personals Corpus
# text9: The Man Who Was Thursday by G . K . Chesterton 1908

# %%
import random as rd
a = [len(set(rd.choices(book.text1,k=40000)))/40000 for i in range(50)]
print('average Type/Token ratio =', round(sum(a)/len(a),3))
# Out:
# average Type/Token ratio = 0.167

# %%
a = [len(set(j))/len(j) for j in 
    [rd.choices(book.text1,k=40000) for i in range(50)]]
print('average Type/Token ratio =', round(sum(a)/len(a),3))
# Out:
# average Type/Token ratio = 0.167

# %%
[rd.choices(book.text1,k=40000) for i in range(50)]
# Out:
# [['many',
#   'And',
#   'only',
#   'were',
#   ',',
#   'forecastle',
#   'armed',
#   'of',
#   '.',
#   'is',
#   'THE',
#   '.',
#   'would',
#   'and',
#   'knows',
#   'crotchets',
#   'based',
#   'grapes',
#   'his',
#   'shipmates',
#   'before',
#   'with',
#   ',',
#   'plum',
#   'but',
#   'he',
#   'owner',
#   'by',
#   'is',
#   'away',
#   'a',
#   'business',
#   'Whales',
#   'western',
#   'a',
#   'part',
#   'the',
#   'his',
#   'peeped',
#   'Meantime',
#   'his',
#   'before',
#   'the',
#   'cocks',
#   'his',
#   'is',
#   'a',
#   'little',
#   'succeeded',
#   'casts',
#   'in',
#   'expand',
#   'the',
#   'neighbour',
#   'Pharaoh',
#   'presided',
#   '.',
#   '!',
#   'peep',
#   'whale',
#   'of',
#   'found',
#   'unwonted',
#   'thus',
#   'gallied',
#   ',',
#   ',',
#   '.',
#   'oxen',
#   'in',
#   'at',
#   'a',
#   ',',
#   ',',
#   'you',
#   'he',
#   'may',
#   'in',
#   'best',
#   'and',
#   'self',
#   'and',
#   'to',
#   'of',
#   'you',
#   'last',
#   'of',
#   'to',
#   'a',
#   'Now',
#   'much',
#   'and',
#   'Italian',
#   'that',
#   'your',
#   'swallowed',
#   '.',
#   'a',
#   'All',
#   'gnarled',
#   'purpose',
#   'Bonneterre',
#   'now',
#   'thy',
#   'weary',
#   ',',
#   'himself',
#   'whale',
#   'a',
#   'written',
#   'had',
#   'old',
#   'described',
#   'cards',
#   'all',
#   'the',
#   ',',
#   'with',
#   'mundane',
#   'you',
#   'the',
#   'and',
#   'way',
#   'that',
#   'the',
#   ',',
#   'their',
#   '!"',
#   'look',
#   'is',
#   '-',
#   'tides',
#   'bits',
#   '--"',
#   'step',
#   ',',
#   'miles',
#   ',',
#   '-',
#   'separate',
#   ',',
#   's',
#   '.',
#   'in',
#   '.',
#   'things',
#   ',',
#   'treated',
#   ',',
#   'any',
#   'for',
#   'the',
#   'behold',
#   'the',
#   'had',
#   'brain',
#   ',',
#   'virtue',
#   'wing',
#   'the',
#   'substance',
#   'tail',
#   'ocean',
#   'face',
#   'will',
#   'Ahab',
#   'tell',
#   'There',
#   'carving',
#   'while',
#   ',',
#   'pulpits',
#   'certain',
#   'me',
#   ';',
#   'interfusing',
#   'by',
#   'obituary',
#   '.',
#   'whale',
#   'unimaginable',
#   'the',
#   'a',
#   'and',
#   'exhaled',
#   'the',
#   'a',
#   'mild',
#   'never',
#   'his',
#   'the',
#   'Westers',
#   'last',
#   'have',
#   ',',
#   'To',
#   'die',
#   'glowing',
#   'of',
#   'most',
#   'His',
#   'thou',
#   'thou',
#   'artificial',
#   ',',
#   'will',
#   'of',
#   ',',
#   'tigers',
#   'sunrise',
#   'once',
#   'discreet',
#   'thou',
#   'it',
#   'Right',
#   'and',
#   '.',
#   ',',
#   'yet',
#   '.',
#   'that',
#   'greatest',
#   'Nantucketer',
#   'moaning',
#   'perpendicular',
#   "'",
#   'a',
#   'monster',
#   'be',
#   '!',
#   'these',
#   '!',
#   'the',
#   ',"',
#   'solemnly',
#   'and',
#   '.',
#   'way',
#   'give',
#   'swears',
#   'same',
#   ',',
#   'breeze',
#   'lodged',
#   't',
#   'body',
#   'forger',
#   'we',
#   'involved',
#   'sounding',
#   'spar',
#   'sir',
#   'all',
#   'off',
#   'conciliating',
#   'about',
#   'the',
#   'up',
#   'you',
#   'motion',
#   's',
#   ';',
#   'the',
#   'nothing',
#   '"',
#   'found',
#   'of',
#   'the',
#   'A',
#   'incredible',
#   'upon',
#   'sea',
#   'Stubb',
#   'to',
#   'one',
#   'shrinking',
#   'yet',
#   'to',
#   'oil',
#   'effect',
#   'sleet',
#   ',',
#   'best',
#   'by',
#   'rise',
#   'and',
#   'unless',
#   'so',
#   'to',
#   'of',
#   'whale',
#   'the',
#   'even',
#   'hung',
#   'and',
#   'the',
#   'is',
#   'subdivisible',
#   'them',
#   'chassee',
#   'and',
#   'noble',
#   'may',
#   'the',
#   'comprised',
#   'drizzly',
#   'a',
#   'bolted',
#   'which',
#   'the',
#   ',',
#   'for',
#   'over',
#   '!--',
#   ',',
#   'cry',
#   'Cetacean',
#   'the',
#   ',',
#   'die',
#   'one',
#   '"',
#   'the',
#   'not',
#   'whale',
#   'of',
#   'his',
#   'tossing',
#   ',',
#   'this',
#   'it',
#   'pagan',
#   '--',
#   'greatly',
#   'he',
#   'and',
#   'and',
#   'while',
#   'the',
#   'last',
#   'with',
#   ',',
#   'fain',
#   'to',
#   '!',
#   'flower',
#   'arm',
#   'grieved',
#   'as',
#   'forecastle',
#   'into',
#   'half',
#   'and',
#   'kneeling',
#   'SNEEZES',
#   ",'",
#   'hull',
#   'but',
#   'pointed',
#   'soul',
#   'it',
#   ',',
#   'say',
#   'one',
#   'therefore',
#   'preliminary',
#   '.',
#   'the',
#   'in',
#   'thrown',
#   'about',
#   ',',
#   'abed',
#   ',',
#   'you',
#   '.',
#   'the',
#   'the',
#   'the',
#   'turbulence',
#   'Death',
#   'itself',
#   'sperm',
#   'But',
#   ',',
#   'man',
#   'and',
#   '-',
#   'hinted',
#   'for',
#   'the',
#   'the',
#   'the',
#   'the',
#   ',',
#   'what',
#   'binnacle',
#   'foam',
#   ',',
#   'to',
#   '.',
#   'they',
#   'so',
#   ';',
#   'without',
#   'would',
#   'but',
#   'viol',
#   'shadowed',
#   'comes',
#   'only',
#   'him',
#   ',',
#   'sides',
#   'do',
#   'slanting',
#   'the',
#   'god',
#   'of',
#   'its',
#   'the',
#   'you',
#   'and',
#   'lip',
#   'and',
#   "'",
#   'aright',
#   'on',
#   ',',
#   ';',
#   'the',
#   ',',
#   'out',
#   'was',
#   'uprising',
#   'pursuit',
#   'idea',
#   ',',
#   'is',
#   'went',
#   ',',
#   'commonplaces',
#   'sire',
#   'the',
#   'stood',
#   'is',
#   'sea',
#   'are',
#   'caking',
#   '--',
#   'might',
#   'is',
#   '-',
#   'baleful',
#   '.',
#   'watch',
#   'which',
#   'than',
#   'with',
#   'in',
#   'with',
#   'God',
#   'license',
#   'laid',
#   ',',
#   'purpose',
#   'the',
#   'a',
#   'white',
#   'him',
#   'I',
#   'it',
#   'dust',
#   'on',
#   ',',
#   ';',
#   "'",
#   'to',
#   ',',
#   'your',
#   'the',
#   'too',
#   'sky',
#   'century',
#   'lying',
#   'or',
#   'the',
#   'stump',
#   ',',
#   'use',
#   'it',
#   'under',
#   ',',
#   'shortly',
#   'little',
#   '"--',
#   'It',
#   'and',
#   ',',
#   'think',
#   'settle',
#   '-',
#   "'",
#   'sun',
#   'wedding',
#   'it',
#   'are',
#   'cleansed',
#   'I',
#   'to',
#   'obligations',
#   'send',
#   'ship',
#   'the',
#   '!"',
#   'been',
#   'on',
#   'Who',
#   'the',
#   'in',
#   'blandness',
#   'floor',
#   'In',
#   ',',
#   'Whale',
#   'IN',
#   'the',
#   'Jonah',
#   'of',
#   'The',
#   'time',
#   '!',
#   'the',
#   'It',
#   'only',
#   '.',
#   'bone',
#   'rope',
#   'whale',
#   'to',
#   '!',
#   'round',
#   'his',
#   'good',
#   ',',
#   'upon',
#   'indifferent',
#   'coast',
#   'would',
#   'waters',
#   'consciousness',
#   'piggledy',
#   'seen',
#   'lively',
#   'of',
#   'the',
#   'fish',
#   'the',
#   'ensigns',
#   'the',
#   'Moby',
#   'the',
#   'each',
#   'strictly',
#   'habits',
#   'now',
#   'reel',
#   'gin',
#   'or',
#   'and',
#   '"',
#   ',"',
#   'm',
#   'the',
#   'expression',
#   'a',
#   'this',
#   'it',
#   'of',
#   '.',
#   'mildly',
#   'juicy',
#   'last',
#   'steel',
#   'here',
#   'lone',
#   'before',
#   'magic',
#   'comprise',
#   '.',
#   'which',
#   'come',
#   'swiftness',
#   'be',
#   'wide',
#   'which',
#   '!',
#   'hear',
#   '?',
#   'in',
#   'and',
#   'them',
#   'in',
#   ',',
#   'some',
#   'crotch',
#   'overboard',
#   'suspending',
#   'of',
#   'of',
#   'and',
#   'I',
#   'most',
#   's',
#   'me',
#   'too',
#   'Stubb',
#   '"',
#   'that',
#   'be',
#   'they',
#   '--',
#   'the',
#   'sea',
#   'induced',
#   'crushed',
#   'themselves',
#   'He',
#   'look',
#   'the',
#   'he',
#   'feet',
#   '"',
#   'I',
#   'aside',
#   'had',
#   'whale',
#   'was',
#   "'",
#   'be',
#   ';',
#   'you',
#   'forward',
#   "'",
#   ',',
#   '!',
#   'the',
#   'when',
#   ',',
#   'thing',
#   'board',
#   'recovered',
#   'a',
#   '"\'',
#   'a',
#   'and',
#   '.',
#   'thing',
#   'woe',
#   '.',
#   'of',
#   'whirling',
#   'half',
#   'the',
#   'aft',
#   'carriage',
#   ';',
#   'as',
#   'are',
#   'leaps',
#   'go',
#   'made',
#   'usual',
#   'not',
#   'the',
#   'we',
#   'aloft',
#   'seemed',
#   'a',
#   'I',
#   'tell',
#   'hid',
#   ',',
#   '.',
#   'the',
#   'outlines',
#   'of',
#   'did',
#   'kissed',
#   'Captain',
#   ',',
#   'English',
#   'it',
#   'may',
#   'psalmody',
#   'one',
#   ',',
#   'is',
#   'who',
#   'marshy',
#   'the',
#   'Glacier',
#   '.',
#   ',',
#   'bones',
#   'in',
#   'the',
#   '!',
#   'spring',
#   'sideboard',
#   'of',
#   'the',
#   'where',
#   ',',
#   'round',
#   '?--',
#   'scolds',
#   'veracity',
#   'line',
#   'jaws',
#   'you',
#   'head',
#   'and',
#   'is',
#   'befallen',
#   'non',
#   'thy',
#   "'",
#   'casks',
#   'fullest',
#   'two',
#   'he',
#   'consternation',
#   ',',
#   'slide',
#   'Captain',
#   'said',
#   'and',
#   'There',
#   'longer',
#   'ghost',
#   'Capting',
#   'roaring',
#   'hundreds',
#   'sea',
#   'lords',
#   '?',
#   'what',
#   'and',
#   'cabin',
#   'that',
#   ')',
#   'of',
#   'rocks',
#   'on',
#   'Starbuck',
#   'the',
#   'that',
#   'stage',
#   'in',
#   'home',
#   'me',
#   ',',
#   'beckoning',
#   'and',
#   'of',
#   'of',
#   'years',
#   'of',
#   'by',
#   'one',
#   "'",
#   ',',
#   'er',
#   ',',
#   'earthly',
#   ',',
#   'short',
#   'of',
#   'can',
#   'the',
#   'now',
#   'the',
#   'to',
#   'the',
#   'on',
#   'But',
#   'extracts',
#   "'",
#   'the',
#   'seas',
#   'of',
#   'one',
#   'Daggoo',
#   'Pequod',
#   'the',
#   ',',
#   'Thus',
#   'that',
#   's',
#   'soul',
#   'craft',
#   'I',
#   'cask',
#   "'",
#   'in',
#   ';',
#   'the',
#   'from',
#   '-',
#   'the',
#   ',',
#   'excluding',
#   'mentioned',
#   'tinkling',
#   'creamy',
#   'all',
#   'loudly',
#   'hammock',
#   'cried',
#   'good',
#   ',',
#   'is',
#   ',',
#   'advances',
#   'the',
#   '?',
#   'be',
#   'longer',
#   'can',
#   'general',
#   'after',
#   'for',
#   'any',
#   'furled',
#   'myself',
#   '.',
#   'no',
#   'at',
#   'boarders',
#   ',',
#   'Stubb',
#   'deepest',
#   'some',
#   'recrossing',
#   'way',
#   'too',
#   'crew',
#   ',',
#   'he',
#   'the',
#   'over',
#   'starlight',
#   'the',
#   'a',
#   'Antilles',
#   'Lose',
#   ';',
#   'shivered',
#   'hung',
#   'directly',
#   'his',
#   'into',
#   'is',
#   ',',
#   'gurglings',
#   'thought',
#   'the',
#   'to',
#   'Whale',
#   'more',
#   'he',
#   'voyage',
#   'whale',
#   'door',
#   ',',
#   'these',
#   'has',
#   'the',
#   'sea',
#   'hunter',
#   'but',
#   'heart',
#   'would',
#   'Pip',
#   'my',
#   'old',
#   'the',
#   'make',
#   'encountered',
#   'same',
#   'been',
#   '"',
#   ',',
#   'strip',
#   'And',
#   'and',
#   'Isle',
#   '--',
#   'and',
#   'these',
#   'I',
#   '.',
#   'is',
#   'only',
#   'where',
#   'daunted',
#   'beginning',
#   'significance',
#   'swung',
#   'and',
#   'off',
#   'Such',
#   '!',
#   '.',
#   'thickening',
#   'meadow',
#   'the',
#   'God',
#   'he',
#   'a',
#   'crabs',
#   'such',
#   'abandoned',
#   'himself',
#   'that',
#   'unobservant',
#   '!',
#   'upon',
#   'flames',
#   'here',
#   '.',
#   'upon',
#   'at',
#   'the',
#   'Sleet',
#   'leviathan',
#   'that',
#   'and',
#   'days',
#   ',',
#   'it',
#   '!"',
#   'firmly',
#   'the',
#   'gravity',
#   'must',
#   'shall',
#   'a',
#   '"\'',
#   'you',
#   'of',
#   'groaned',
#   'both',
#   '"',
#   'longer',
#   ',',
#   'the',
#   'what',
#   'A',
#   'even',
#   'the',
#   '"\'',
#   'Gulf',
#   'Heidelburgh',
#   'were',
#   'yet',
#   'said',
#   'the',
#   'cage',
#   "'",
#   'door',
#   'God',
#   ',',
#   'said',
#   'of',
#   'monomaniac',
#   'of',
#   'white',
#   'But',
#   'here',
#   'thrust',
#   'the',
#   'of',
#   ',',
#   'soft',
#   'at',
#   'subsequently',
#   'wild',
#   'completed',
#   've',
#   'see',
#   'sometimes',
#   'and',
#   'with',
#   'on',
#   'scornest',
#   'imperial',
#   'as',
#   'the',
#   ...],
#  ['charitable',
#   'our',
#   'honest',
#   'one',
#   'then',
#   'officer',
#   'thistle',
#   ',',
#   '.',
#   'Captain',
#   'nearer',
#   'outrageous',
#   'Within',
#   'mistrust',
#   'founded',
#   ',',
#   's',
#   'I',
#   'and',
#   'that',
#   'after',
#   'and',
#   ',',
#   ',',
#   'not',
#   'and',
#   'this',
#   ',',
#   ',',
#   's',
#   'quite',
#   '.',
#   "'",
#   'upright',
#   'I',
#   'you',
#   '--',
#   ',',
#   'him',
#   'and',
#   'element',
#   'when',
#   'volcanoes',
#   'of',
#   'the',
#   'at',
#   'strangest',
#   'oftentimes',
#   '.',
#   ',',
#   'Jonah',
#   'Are',
#   'was',
#   'now',
#   'I',
#   'landed',
#   'it',
#   ',"',
#   'perils',
#   ',',
#   'wreck',
#   'at',
#   'music',
#   'cried',
#   'manner',
#   'patchwork',
#   'and',
#   'midmost',
#   'each',
#   'in',
#   'last',
#   'as',
#   'water',
#   'for',
#   'is',
#   'aspect',
#   'though',
#   'bed',
#   'can',
#   'night',
#   'the',
#   ';',
#   'have',
#   ',',
#   '--',
#   'looked',
#   'hand',
#   ',',
#   ',',
#   'over',
#   'he',
#   'the',
#   'as',
#   'very',
#   'somewhat',
#   'But',
#   'the',
#   'hands',
#   'whale',
#   'come',
#   'to',
#   ',',
#   'into',
#   'credulous',
#   'satisfied',
#   'ever',
#   'whales',
#   'in',
#   'glasses',
#   'possible',
#   '.',
#   'cabin',
#   'system',
#   '.',
#   'of',
#   'palsy',
#   ',',
#   'the',
#   'her',
#   'have',
#   'to',
#   'once',
#   'gentlemen',
#   'you',
#   'wine',
#   'last',
#   'of',
#   'SAILOR',
#   'travel',
#   'History',
#   'stare',
#   'stand',
#   '(',
#   'a',
#   ',',
#   'his',
#   'casks',
#   'prepared',
#   'and',
#   'it',
#   'stood',
#   'whether',
#   'the',
#   '-',
#   ',',
#   'in',
#   'is',
#   'sufficient',
#   'rolled',
#   'harpoons',
#   'skin',
#   ',',
#   'Franklin',
#   'dinner',
#   'from',
#   'of',
#   'no',
#   'But',
#   'cogent',
#   'dropping',
#   ',',
#   'by',
#   'which',
#   '.',
#   'in',
#   ',',
#   'truth',
#   'they',
#   'that',
#   'his',
#   'But',
#   'bursting',
#   'of',
#   'ahead',
#   'some',
#   'of',
#   ',',
#   'match',
#   'to',
#   'I',
#   'of',
#   'procession',
#   'aloft',
#   'here',
#   'of',
#   'an',
#   ',',
#   'by',
#   'only',
#   'of',
#   '.',
#   '?',
#   'on',
#   'horse',
#   'crowded',
#   'of',
#   'Tell',
#   'spinal',
#   'glance',
#   '?',
#   'an',
#   'sight',
#   'gradually',
#   ',',
#   'rushing',
#   'all',
#   'shivered',
#   'the',
#   'moving',
#   'so',
#   'll',
#   'large',
#   'because',
#   'in',
#   'cheek',
#   'stretch',
#   ';',
#   'gave',
#   '?',
#   'to',
#   'brooks',
#   'to',
#   'ne',
#   'I',
#   'mariners',
#   'and',
#   'to',
#   ',',
#   'its',
#   'rope',
#   'his',
#   'figured',
#   'fin',
#   'the',
#   'the',
#   'breeze',
#   'that',
#   '.',
#   'fain',
#   'But',
#   'rather',
#   'digesting',
#   'then',
#   'to',
#   'to',
#   'are',
#   'there',
#   'too',
#   'number',
#   'are',
#   'and',
#   'more',
#   'to',
#   ';',
#   ',',
#   'young',
#   '"',
#   'widest',
#   'or',
#   'Try',
#   'a',
#   "'",
#   '.',
#   'strange',
#   '.',
#   'whispered',
#   'it',
#   'crew',
#   'operation',
#   'an',
#   '"',
#   'its',
#   'there',
#   "!'",
#   'and',
#   's',
#   'SPERM',
#   'him',
#   'brow',
#   'cast',
#   'History',
#   'here',
#   'the',
#   ',',
#   'chamois',
#   'rather',
#   'out',
#   "'",
#   'the',
#   'himself',
#   'look',
#   'the',
#   "?'",
#   'he',
#   's',
#   'already',
#   'way',
#   'railways',
#   'of',
#   'the',
#   'over',
#   'present',
#   'where',
#   'tell',
#   'yet',
#   'that',
#   'the',
#   'then',
#   ';',
#   ',',
#   'from',
#   'the',
#   'what',
#   'eddying',
#   'one',
#   ',',
#   'casually',
#   'light',
#   'But',
#   'while',
#   'shipmates',
#   ',',
#   'to',
#   'Peleg',
#   'me',
#   'a',
#   'upon',
#   'No',
#   'superhuman',
#   'out',
#   'but',
#   'by',
#   'the',
#   'of',
#   ',',
#   'tail',
#   'when',
#   'but',
#   'historic',
#   'his',
#   'sorry',
#   'slightly',
#   'that',
#   'me',
#   'shall',
#   'Old',
#   'a',
#   'hull',
#   'was',
#   'little',
#   'a',
#   'hereabouts',
#   'Diving',
#   'one',
#   'beams',
#   ',',
#   'remained',
#   'into',
#   'flames',
#   ',',
#   ',',
#   'the',
#   'fountains',
#   'pyramid',
#   ',',
#   'fold',
#   'into',
#   'known',
#   "'",
#   'What',
#   'out',
#   '"',
#   'unnearable',
#   'the',
#   'have',
#   'a',
#   'me',
#   'they',
#   'Justinian',
#   'the',
#   'climb',
#   '.',
#   'the',
#   'Lakeman',
#   'and',
#   'be',
#   'compasses',
#   '-',
#   'a',
#   'daresn',
#   'worn',
#   'the',
#   ',',
#   'few',
#   'were',
#   'into',
#   'somehow',
#   'S',
#   'the',
#   'and',
#   'much',
#   'the',
#   'side',
#   'damn',
#   'sir',
#   'to',
#   'for',
#   'nourished',
#   'the',
#   'Moreover',
#   '.',
#   'spring',
#   'the',
#   'hundred',
#   'the',
#   'advance',
#   'ships',
#   'night',
#   'SPOUTING',
#   'of',
#   "'",
#   'at',
#   'himself',
#   'by',
#   'goes',
#   'inward',
#   'the',
#   'of',
#   'suddenly',
#   'him',
#   'old',
#   'man',
#   'I',
#   'For',
#   'were',
#   'Nevertheless',
#   'that',
#   'have',
#   'and',
#   'Nun',
#   'nothing',
#   '-',
#   'intercedings',
#   'where',
#   '.',
#   'perhaps',
#   'irons',
#   'at',
#   'feeding',
#   'that',
#   'one',
#   'leap',
#   'a',
#   'In',
#   'however',
#   'had',
#   'celled',
#   'in',
#   'if',
#   'I',
#   'a',
#   'too',
#   'and',
#   'every',
#   'of',
#   ';',
#   'apparition',
#   'level',
#   'the',
#   'escaping',
#   'Fleet',
#   'full',
#   'Ahab',
#   'though',
#   'But',
#   'land',
#   'of',
#   'there',
#   'upon',
#   'all',
#   'life',
#   'circle',
#   'all',
#   'on',
#   'carpenter',
#   'We',
#   ',',
#   ',',
#   'mean',
#   "'",
#   'on',
#   'shuddering',
#   'the',
#   'fell',
#   'with',
#   'even',
#   'grey',
#   'for',
#   ',',
#   'billows',
#   'in',
#   'well',
#   'to',
#   'don',
#   'that',
#   'Stubb',
#   '-',
#   'a',
#   'the',
#   'head',
#   'tinker',
#   'lowerings',
#   'space',
#   'in',
#   ';',
#   '--',
#   ',',
#   'in',
#   'by',
#   'REQUIN',
#   'about',
#   'but',
#   ',',
#   'Just',
#   'twain',
#   'certainly',
#   'and',
#   ',',
#   'Leviathan',
#   'think',
#   'of',
#   'll',
#   'that',
#   'I',
#   'sperm',
#   'and',
#   'the',
#   'of',
#   ',',
#   'by',
#   ',',
#   'up',
#   'needs',
#   'out',
#   'ascended',
#   'the',
#   'of',
#   'lower',
#   'his',
#   'every',
#   'speak',
#   'now',
#   'deck',
#   'Certainly',
#   ';',
#   'to',
#   'clenched',
#   'So',
#   'undone',
#   'sparing',
#   'the',
#   'their',
#   'in',
#   'rush',
#   'not',
#   '.',
#   'the',
#   'him',
#   ',',
#   'thoroughly',
#   'had',
#   'enormous',
#   'the',
#   'sinking',
#   'all',
#   'precise',
#   ',',
#   'ox',
#   'Libra',
#   'or',
#   'before',
#   ',',
#   'he',
#   'deck',
#   'beseech',
#   'now',
#   'there',
#   'about',
#   'pallidness',
#   '!"',
#   'plane',
#   'It',
#   'intimacy',
#   '--',
#   ',',
#   'it',
#   'scrutinizing',
#   'unimaginable',
#   ',',
#   'one',
#   ',',
#   "'",
#   ',"',
#   'dumbly',
#   "!'",
#   ',',
#   '3',
#   'person',
#   'bolder',
#   'fossil',
#   'confounded',
#   'fluttering',
#   'Queequeg',
#   'old',
#   'by',
#   'from',
#   'all',
#   'he',
#   '"',
#   'seemed',
#   'and',
#   'poor',
#   'thousand',
#   'broke',
#   'before',
#   'had',
#   'that',
#   'fearful',
#   'the',
#   'unreasoning',
#   'species',
#   'old',
#   'in',
#   'his',
#   'warm',
#   'you',
#   'ship',
#   'thought',
#   '!--',
#   'the',
#   'the',
#   'that',
#   'and',
#   '-',
#   'themselves',
#   'them',
#   'all',
#   'market',
#   'published',
#   'The',
#   'whale',
#   'be',
#   'came',
#   '"',
#   'of',
#   'of',
#   'almost',
#   ',',
#   'not',
#   'his',
#   'see',
#   'occurrence',
#   'coast',
#   '?',
#   'while',
#   'to',
#   'tamely',
#   'water',
#   'it',
#   ';',
#   'air',
#   'calculating',
#   'along',
#   'look',
#   'his',
#   'in',
#   ',',
#   'old',
#   'Whaling',
#   'bill',
#   'hunters',
#   'calf',
#   '50',
#   'a',
#   'never',
#   'so',
#   'round',
#   'Or',
#   't',
#   'bull',
#   'of',
#   'of',
#   'his',
#   'to',
#   'and',
#   'in',
#   'of',
#   'is',
#   'of',
#   'and',
#   'whom',
#   'them',
#   'myself',
#   'prices',
#   ';',
#   ',',
#   'very',
#   'archipelagoes',
#   "'",
#   'Titans',
#   'milky',
#   'cut',
#   'ye',
#   'iron',
#   'taking',
#   'Reference',
#   'a',
#   'it',
#   ',',
#   'through',
#   '.',
#   'jumbled',
#   'perhaps',
#   'it',
#   'said',
#   'out',
#   'of',
#   'horrible',
#   'we',
#   'tutored',
#   'hoisted',
#   'the',
#   '.',
#   'the',
#   'the',
#   ',',
#   'visible',
#   'cabalistics',
#   'world',
#   'should',
#   'over',
#   '.',
#   'but',
#   '.',
#   'The',
#   'one',
#   'invisible',
#   'was',
#   '?',
#   '-',
#   'mapped',
#   'On',
#   ',',
#   'mountain',
#   'jets',
#   'with',
#   'they',
#   'Queequeg',
#   'with',
#   'to',
#   'at',
#   'handled',
#   'up',
#   'Dick',
#   'esteem',
#   'RECLINING',
#   'so',
#   'height',
#   'of',
#   'the',
#   'soon',
#   'enjoined',
#   ',',
#   'Bildad',
#   'well',
#   'his',
#   'of',
#   '!--',
#   'little',
#   ',',
#   ';',
#   'black',
#   'voyages',
#   'the',
#   'turned',
#   'horizon',
#   'snow',
#   'substitute',
#   'and',
#   'the',
#   'to',
#   '.',
#   '"',
#   'sharpening',
#   'head',
#   "'",
#   'or',
#   'last',
#   'swung',
#   'forswearing',
#   'is',
#   'It',
#   ',',
#   'I',
#   'while',
#   'high',
#   'noisy',
#   'wooden',
#   'insensible',
#   'his',
#   'cartload',
#   'he',
#   'the',
#   'predicament',
#   ',',
#   'was',
#   'the',
#   'this',
#   'bond',
#   'knocking',
#   'business',
#   'it',
#   'of',
#   'seemed',
#   'the',
#   'to',
#   'pull',
#   'for',
#   'a',
#   'proportion',
#   'a',
#   'of',
#   'Come',
#   'head',
#   'resolution',
#   'as',
#   '.',
#   'eager',
#   'and',
#   'It',
#   ';',
#   'ivory',
#   'the',
#   'sinking',
#   'seemed',
#   'she',
#   'being',
#   ';',
#   'with',
#   ';',
#   'The',
#   ',',
#   'forecastle',
#   'stumps',
#   '.--',
#   'hole',
#   'for',
#   'us',
#   'even',
#   'in',
#   'to',
#   'to',
#   'the',
#   'found',
#   'seen',
#   'floating',
#   'him',
#   'pork',
#   'may',
#   'east',
#   ';',
#   "'",
#   'over',
#   'light',
#   '-',
#   'in',
#   'saw',
#   'let',
#   'of',
#   'perhaps',
#   'water',
#   'to',
#   'comprehend',
#   'Flask',
#   'quiver',
#   'in',
#   'entire',
#   'one',
#   'Laws',
#   'creature',
#   'his',
#   'at',
#   'respect',
#   'a',
#   'round',
#   'him',
#   '?"',
#   ',',
#   'but',
#   '-',
#   'a',
#   'that',
#   'has',
#   'and',
#   'up',
#   'had',
#   'coming',
#   ',',
#   'leaking',
#   'from',
#   'was',
#   'em',
#   'thought',
#   'Look',
#   'light',
#   'by',
#   'done',
#   'she',
#   'age',
#   'a',
#   'and',
#   ',',
#   ',',
#   'yard',
#   'day',
#   'that',
#   'Seems',
#   ':',
#   'NARRATIVE',
#   'ignorant',
#   'request',
#   'But',
#   'mast',
#   'his',
#   'his',
#   'he',
#   'whaling',
#   'Cachalot',
#   'beneath',
#   'of',
#   'Down',
#   'that',
#   'like',
#   'ships',
#   'deadly',
#   'two',
#   'small',
#   'metropolitan',
#   'expected',
#   'And',
#   'Mt',
#   'to',
#   'in',
#   'the',
#   'whale',
#   "'",
#   'a',
#   'yet',
#   ',',
#   'passengers',
#   'the',
#   'account',
#   'entrance',
#   'obvious',
#   'our',
#   ',',
#   'French',
#   'a',
#   "'",
#   'to',
#   'her',
#   '--',
#   'in',
#   'Among',
#   'about',
#   'scholar',
#   ',',
#   'sailings',
#   'touched',
#   'is',
#   'man',
#   'had',
#   'but',
#   'stranded',
#   'the',
#   'stone',
#   'Moby',
#   'for',
#   'over',
#   'single',
#   'nor',
#   'Almost',
#   'It',
#   '&',
#   'seen',
#   'a',
#   'upon',
#   'not',
#   ',',
#   'true',
#   ...],
#  [';',
#   'captains',
#   'length',
#   'however',
#   'until',
#   'and',
#   'execute',
#   'spread',
#   'recorded',
#   'there',
#   'scar',
#   'Don',
#   'senate',
#   'thorns',
#   ';',
#   'again',
#   'the',
#   'as',
#   'I',
#   'sort',
#   'all',
#   'every',
#   'the',
#   'about',
#   '"',
#   'of',
#   'stab',
#   ',',
#   ',',
#   'five',
#   'if',
#   ',',
#   'the',
#   ',--',
#   '.',
#   'one',
#   'the',
#   'whalers',
#   'last',
#   'Retribution',
#   'whale',
#   'imposed',
#   'as',
#   'Ishmael',
#   'when',
#   'had',
#   'but',
#   'not',
#   'tablets',
#   'said',
#   'true',
#   'cutting',
#   'the',
#   'bold',
#   ',',
#   'the',
#   'the',
#   'decent',
#   'perched',
#   'one',
#   'pondering',
#   'a',
#   'jaw',
#   'commanded',
#   'second',
#   'morning',
#   'of',
#   'spat',
#   'darkly',
#   'man',
#   'brig',
#   'for',
#   'sudden',
#   'confluent',
#   'a',
#   'perceived',
#   "'",
#   'baptism',
#   'luck',
#   "'",
#   'come',
#   'the',
#   'go',
#   'that',
#   'vainly',
#   'each',
#   'School',
#   '--',
#   'that',
#   ',',
#   't',
#   'thou',
#   'a',
#   "'",
#   'the',
#   'a',
#   'not',
#   ',',
#   'dawn',
#   'crow',
#   'Nantucket',
#   'Crotch',
#   'down',
#   'a',
#   'must',
#   'the',
#   'a',
#   ',',
#   ',',
#   'of',
#   'this',
#   'I',
#   'leave',
#   'of',
#   'straight',
#   'upon',
#   '.',
#   'implement',
#   'white',
#   'goes',
#   'the',
#   'were',
#   'into',
#   'even',
#   ',',
#   'forking',
#   'swearing',
#   'animals',
#   'whose',
#   ",'",
#   'in',
#   'his',
#   'perils',
#   'man',
#   'two',
#   '.',
#   'that',
#   'felt',
#   'look',
#   'wondrous',
#   'an',
#   'tapering',
#   '."',
#   'the',
#   'E',
#   'most',
#   'respect',
#   'of',
#   'its',
#   'said',
#   'looking',
#   ',',
#   '.',
#   'him',
#   'important',
#   'he',
#   'to',
#   'think',
#   'toiled',
#   'me',
#   'so',
#   'FROM',
#   ',',
#   'soon',
#   'a',
#   'to',
#   'our',
#   'I',
#   ',',
#   'breadth',
#   ',',
#   'on',
#   'were',
#   'to',
#   'again',
#   'a',
#   'chief',
#   'that',
#   'dodging',
#   'But',
#   'are',
#   'of',
#   'spiralizing',
#   'from',
#   'Then',
#   'it',
#   'the',
#   'she',
#   'must',
#   'saw',
#   'lowering',
#   ',',
#   'then',
#   'barbaric',
#   'annually',
#   'circular',
#   'outline',
#   ',',
#   'somehow',
#   'what',
#   ',',
#   'dietetically',
#   'about',
#   'with',
#   'it',
#   'they',
#   "'",
#   'crotch',
#   'and',
#   'Stubb',
#   'than',
#   'lone',
#   ',',
#   'up',
#   'old',
#   'heaven',
#   'beget',
#   'by',
#   'will',
#   'heads',
#   "'",
#   'Nantucket',
#   'an',
#   ',',
#   'with',
#   'Rose',
#   'an',
#   'back',
#   'most',
#   'wriggling',
#   'in',
#   'cloth',
#   'there',
#   'To',
#   'inasmuch',
#   '!',
#   'ghost',
#   'nowise',
#   'a',
#   'the',
#   'his',
#   'of',
#   'up',
#   'like',
#   'leagues',
#   'augment',
#   'but',
#   'the',
#   'of',
#   'coast',
#   'lord',
#   'first',
#   'Ahab',
#   'leave',
#   'Death',
#   'I',
#   '.',
#   'is',
#   'of',
#   'being',
#   'than',
#   'from',
#   'enveloped',
#   'lacquered',
#   'and',
#   'heart',
#   'bowed',
#   's',
#   'contemporary',
#   'all',
#   'business',
#   'time',
#   'continual',
#   'rough',
#   'losing',
#   'perpendicular',
#   'drawing',
#   'schools',
#   'now',
#   'boat',
#   'up',
#   'height',
#   "'",
#   '"',
#   'one',
#   'you',
#   'over',
#   'There',
#   'at',
#   'the',
#   'trouble',
#   'tattooing',
#   'soul',
#   'by',
#   'earth',
#   ',',
#   'the',
#   'survey',
#   'time',
#   'threads',
#   'they',
#   'sound',
#   'the',
#   ',',
#   'seemed',
#   'of',
#   'Banks',
#   'shadow',
#   "'",
#   "'",
#   'never',
#   ',',
#   ',',
#   'could',
#   'slain',
#   'trying',
#   ':',
#   'quarried',
#   'For',
#   'other',
#   '.',
#   'an',
#   'all',
#   'go',
#   'strange',
#   'and',
#   'in',
#   'HIM',
#   'here',
#   'out',
#   'room',
#   'That',
#   'short',
#   'should',
#   'recorded',
#   'had',
#   'from',
#   'fold',
#   '.',
#   'jaws',
#   'of',
#   'thing',
#   'OLD',
#   'Vineyard',
#   'and',
#   'as',
#   'cough',
#   'HIS',
#   'of',
#   'OF',
#   'beneath',
#   'churning',
#   'in',
#   'I',
#   ',',
#   'their',
#   'the',
#   'thoughtful',
#   ',',
#   'arm',
#   'these',
#   'be',
#   'ready',
#   '.',
#   'quiescence',
#   ',"',
#   ';',
#   'What',
#   'So',
#   'appearance',
#   'and',
#   'the',
#   ',',
#   'forward',
#   'shipmate',
#   'for',
#   ',',
#   'Ahab',
#   's',
#   'no',
#   ',',
#   'lost',
#   'then',
#   'chest',
#   'a',
#   'milk',
#   'him',
#   'Loose',
#   'He',
#   'hereby',
#   "'",
#   'to',
#   'are',
#   'madness',
#   'than',
#   '.',
#   '.*',
#   'destroyed',
#   'WHALE',
#   'for',
#   'been',
#   'reference',
#   'in',
#   'to',
#   'of',
#   'impartial',
#   '-',
#   'goes',
#   'the',
#   'as',
#   'Bildad',
#   '-',
#   '"',
#   'kill',
#   'every',
#   'had',
#   'not',
#   ',',
#   '.',
#   'as',
#   ',',
#   'God',
#   'But',
#   'the',
#   'called',
#   'family',
#   'frosty',
#   'tossed',
#   'that',
#   'there',
#   ',',
#   'the',
#   'that',
#   ';',
#   's',
#   '9',
#   ',',
#   'thoughts',
#   '.',
#   'at',
#   'to',
#   'can',
#   '-',
#   'stopping',
#   'ash',
#   'favour',
#   '-',
#   'from',
#   'at',
#   'gather',
#   'by',
#   'flame',
#   'their',
#   'from',
#   'Prynne',
#   'fain',
#   'one',
#   "'",
#   'shipmates',
#   'found',
#   'else',
#   ';',
#   'tree',
#   'Boy',
#   'though',
#   'had',
#   'sailor',
#   'lion',
#   'air',
#   'there',
#   '!--',
#   'mark',
#   'she',
#   ',',
#   '.*',
#   'that',
#   'husks',
#   'Starbuck',
#   'book',
#   'lobes',
#   'by',
#   'is',
#   'elderly',
#   'the',
#   '--',
#   'a',
#   'known',
#   'after',
#   'perils',
#   'harmless',
#   '-',
#   'kiln',
#   'I',
#   'that',
#   'be',
#   'in',
#   'For',
#   'that',
#   'darkly',
#   'churchyard',
#   'in',
#   'of',
#   ',',
#   'for',
#   ',',
#   'uncommonly',
#   'and',
#   'thing',
#   'newly',
#   'and',
#   'replied',
#   'violence',
#   'taken',
#   ';',
#   'suburbs',
#   'and',
#   'a',
#   '--',
#   'ice',
#   'the',
#   's',
#   'its',
#   ',',
#   'wounded',
#   'have',
#   'universal',
#   'thing',
#   'not',
#   'that',
#   'most',
#   'look',
#   ',',
#   'firmament',
#   'loveliness',
#   'whole',
#   'of',
#   'torn',
#   'by',
#   'troubled',
#   'Now',
#   'to',
#   'And',
#   ',',
#   'all',
#   'hill',
#   'old',
#   'there',
#   'happens',
#   'some',
#   ',',
#   ';',
#   ';',
#   'ruffled',
#   'his',
#   'himself',
#   'charm',
#   ',',
#   ',',
#   'and',
#   'boys',
#   'if',
#   '!',
#   'little',
#   '.',
#   'that',
#   'harp',
#   '"',
#   'than',
#   'religious',
#   'other',
#   ';',
#   'allay',
#   'stalwart',
#   'where',
#   'Whale',
#   'sociably',
#   'Starbuck',
#   'kind',
#   ',',
#   'that',
#   'to',
#   'be',
#   ',',
#   'fear',
#   'troubled',
#   'CHAPTER',
#   's',
#   'feel',
#   'OF',
#   'for',
#   'who',
#   'leviathan',
#   'Come',
#   't',
#   'the',
#   '"\'',
#   'with',
#   'ere',
#   'Ahab',
#   'among',
#   'was',
#   'thee',
#   'bruited',
#   'personality',
#   'each',
#   'this',
#   'the',
#   'the',
#   'Well',
#   'linear',
#   'blast',
#   ',',
#   '440',
#   'that',
#   'tackles',
#   ',',
#   'nigh',
#   'not',
#   'that',
#   "'",
#   'his',
#   'pipe',
#   'opinion',
#   'with',
#   'a',
#   'the',
#   'them',
#   'a',
#   'broad',
#   'well',
#   'then',
#   'sea',
#   'that',
#   'ordinary',
#   'one',
#   'shares',
#   ',',
#   ',',
#   'time',
#   'fowl',
#   'cherry',
#   'only',
#   'retreats',
#   'so',
#   'what',
#   'of',
#   ',',
#   'the',
#   'silvery',
#   'floating',
#   'little',
#   "'",
#   'often',
#   'was',
#   'proud',
#   'with',
#   'my',
#   'the',
#   'and',
#   'you',
#   'running',
#   'in',
#   'staff',
#   'out',
#   'large',
#   'PRESSED',
#   ';',
#   'which',
#   'is',
#   'crew',
#   'they',
#   'that',
#   'whispering',
#   ',',
#   ',',
#   'bears',
#   ',',
#   'think',
#   ',',
#   'and',
#   'it',
#   'heads',
#   'leaping',
#   'over',
#   'his',
#   'There',
#   'portions',
#   'second',
#   'takes',
#   's',
#   'a',
#   'only',
#   'trophy',
#   'rapidly',
#   'was',
#   'headmost',
#   'such',
#   'red',
#   'Future',
#   'do',
#   'fresher',
#   'and',
#   'far',
#   'EX',
#   'just',
#   'command',
#   ',',
#   ',"',
#   ',',
#   'yet',
#   'where',
#   'worsted',
#   '--"',
#   'whirling',
#   'raised',
#   'not',
#   'shipmates',
#   'vesture',
#   'to',
#   'freely',
#   'eyes',
#   'seemed',
#   'earth',
#   'stern',
#   'his',
#   'Ishmael',
#   'the',
#   'the',
#   ';',
#   ',',
#   'coming',
#   'man',
#   ',',
#   'some',
#   ',',
#   'mile',
#   'and',
#   'rays',
#   ',',
#   'Truth',
#   'the',
#   'operations',
#   'Sperm',
#   ';',
#   'line',
#   'could',
#   'jolly',
#   'strikes',
#   'in',
#   '"',
#   'a',
#   'it',
#   ',',
#   '?',
#   'pierced',
#   'voyaging',
#   'sideways',
#   'strange',
#   ',',
#   ';',
#   'the',
#   'is',
#   ',',
#   'and',
#   'cross',
#   'any',
#   'these',
#   'Town',
#   'whole',
#   'as',
#   'mighty',
#   'that',
#   'down',
#   'the',
#   'he',
#   'savagery',
#   'clotting',
#   ',',
#   'and',
#   'upon',
#   'they',
#   'with',
#   '.',
#   '.',
#   'head',
#   'Rope',
#   '.',
#   'would',
#   'it',
#   'on',
#   'I',
#   'And',
#   'the',
#   'what',
#   'into',
#   'flag',
#   'this',
#   '.',
#   'unfold',
#   'hereafter',
#   'going',
#   'familiar',
#   '"',
#   'at',
#   'savage',
#   'my',
#   'deploy',
#   'deck',
#   'Queequeg',
#   'it',
#   'next',
#   'been',
#   'outer',
#   'time',
#   'heartless',
#   'So',
#   'to',
#   'that',
#   '."',
#   'Aye',
#   'the',
#   ',',
#   'rib',
#   'have',
#   'he',
#   'a',
#   'one',
#   'him',
#   'plainly',
#   'rotund',
#   'anything',
#   'In',
#   'one',
#   'in',
#   'thousand',
#   'throughout',
#   'the',
#   ';',
#   'was',
#   'downright',
#   'miserable',
#   'of',
#   'clothes',
#   'you',
#   'quite',
#   'is',
#   'some',
#   'some',
#   ',',
#   'higher',
#   ',',
#   'a',
#   'private',
#   'pleased',
#   'I',
#   'blows',
#   'Duodecimoes',
#   ',',
#   'he',
#   '!--',
#   'their',
#   'found',
#   'only',
#   'secured',
#   'before',
#   'in',
#   'leaned',
#   'the',
#   'the',
#   'exactly',
#   'black',
#   ',',
#   '.',
#   'turned',
#   'man',
#   'as',
#   'Bedford',
#   'he',
#   'don',
#   ',',
#   'enter',
#   'Stubb',
#   'sprung',
#   '--',
#   'saw',
#   'has',
#   'hour',
#   'leaving',
#   '"',
#   'in',
#   'crowning',
#   'in',
#   'It',
#   'of',
#   'came',
#   'of',
#   'though',
#   'boat',
#   'there',
#   'to',
#   ',',
#   'us',
#   'professor',
#   'and',
#   'ships',
#   'world',
#   '.',
#   'out',
#   'cedar',
#   'beside',
#   'afar',
#   'terrors',
#   'to',
#   'unresting',
#   'axis',
#   '-',
#   'these',
#   '.',
#   'tying',
#   'now',
#   'ten',
#   'line',
#   'over',
#   'this',
#   'spouts',
#   ';',
#   '-',
#   ',',
#   'pouring',
#   ',',
#   'all',
#   'had',
#   'that',
#   'the',
#   'devious',
#   'landlord',
#   'was',
#   'my',
#   '--"',
#   'like',
#   'of',
#   'unassured',
#   'had',
#   'a',
#   ',',
#   ';',
#   'Queequeg',
#   'what',
#   'old',
#   '.',
#   'about',
#   'thy',
#   ',',
#   ',',
#   ',',
#   'and',
#   'it',
#   'bring',
#   'I',
#   'rising',
#   ',',
#   '-',
#   'change',
#   "'",
#   'in',
#   'Bildad',
#   'shark',
#   'mixed',
#   ',',
#   'his',
#   'pointing',
#   'you',
#   'to',
#   'curled',
#   'all',
#   'curious',
#   'three',
#   'encounter',
#   'as',
#   'was',
#   'the',
#   'shall',
#   '.',
#   'each',
#   'Assuredly',
#   'more',
#   'Dick',
#   'inferior',
#   ',',
#   'this',
#   'have',
#   'and',
#   'that',
#   'source',
#   'regular',
#   'Fates',
#   'would',
#   'fathoms',
#   'the',
#   'infant',
#   ...],
#  ['It',
#   'beaters',
#   '.',
#   'put',
#   'sympathetically',
#   'there',
#   'The',
#   'Indian',
#   'the',
#   'advanced',
#   ',',
#   'the',
#   'the',
#   'shape',
#   'tepid',
#   'amain',
#   'and',
#   'most',
#   '.',
#   'him',
#   ',',
#   'recently',
#   'of',
#   'same',
#   'too',
#   ',',
#   ',',
#   'In',
#   'then',
#   'he',
#   'not',
#   '-',
#   'bowsman',
#   'pipe',
#   'Moby',
#   'Ahab',
#   'exactly',
#   'heartless',
#   'being',
#   ',',
#   'heedful',
#   'you',
#   'them',
#   ',',
#   'the',
#   'Enough',
#   'variously',
#   'that',
#   'spades',
#   'fountain',
#   'the',
#   ';',
#   'Thirdly',
#   'you',
#   'some',
#   'upon',
#   'uses',
#   'the',
#   '.',
#   'board',
#   'this',
#   'lowermost',
#   '.',
#   'Fedallah',
#   'was',
#   'tallies',
#   'Steelkilt',
#   'bound',
#   'at',
#   'tow',
#   'that',
#   'South',
#   'still',
#   'it',
#   'every',
#   'Nor',
#   'here',
#   'a',
#   '?',
#   'dashing',
#   'Would',
#   'measure',
#   'on',
#   'that',
#   'swift',
#   'object',
#   'naturalists',
#   'friends',
#   'do',
#   'LEANING',
#   'the',
#   'But',
#   'be',
#   'must',
#   'of',
#   'that',
#   'the',
#   ')',
#   'caved',
#   'like',
#   'in',
#   'when',
#   'the',
#   'not',
#   'called',
#   'wild',
#   ';',
#   'Reckon',
#   'is',
#   'his',
#   'the',
#   'A',
#   'as',
#   'likes',
#   'two',
#   'the',
#   'town',
#   'do',
#   'precise',
#   'plenty',
#   'when',
#   'whaling',
#   'the',
#   'Meanwhile',
#   'presently',
#   's',
#   'iron',
#   ',',
#   'as',
#   'distinct',
#   ',',
#   ',',
#   'conscientious',
#   'I',
#   'left',
#   'in',
#   'Flask',
#   'It',
#   'night',
#   'in',
#   'Steady',
#   "'",
#   'intent',
#   'of',
#   'OCTAVOES',
#   'perch',
#   ',',
#   'from',
#   'keenly',
#   'from',
#   'hustings',
#   'King',
#   'the',
#   'rise',
#   'to',
#   'and',
#   'my',
#   's',
#   'July',
#   'great',
#   'with',
#   'that',
#   'go',
#   '!',
#   '?',
#   'S',
#   'some',
#   ',',
#   'invested',
#   'But',
#   'roll',
#   'indignity',
#   '-',
#   'So',
#   'beneath',
#   'Aye',
#   'the',
#   'same',
#   'up',
#   'is',
#   'burly',
#   'hard',
#   'as',
#   'fisheries',
#   ',',
#   'long',
#   'the',
#   'that',
#   ',',
#   'communications',
#   '1779',
#   'has',
#   'bottom',
#   'hurried',
#   'might',
#   'within',
#   'in',
#   'from',
#   'living',
#   'sperm',
#   'no',
#   ';',
#   'shouted',
#   'plain',
#   'this',
#   'There',
#   's',
#   'iron',
#   'Aye',
#   'gurglings',
#   'fishery',
#   'otherwise',
#   'one',
#   'more',
#   'out',
#   'hauled',
#   'sword',
#   'hat',
#   'his',
#   'know',
#   'of',
#   'How',
#   'to',
#   'his',
#   'being',
#   'of',
#   ',',
#   'back',
#   'is',
#   ',',
#   'hump',
#   'wake',
#   'come',
#   'them',
#   'long',
#   'coiled',
#   'lips',
#   '.',
#   ';',
#   'snatched',
#   'the',
#   'PORPOISE',
#   ';',
#   'of',
#   'ivory',
#   'to',
#   'should',
#   'frayed',
#   'in',
#   'Whale',
#   'Witness',
#   'during',
#   'own',
#   'it',
#   '.',
#   'shipyards',
#   'and',
#   'token',
#   'water',
#   'to',
#   'reasoning',
#   'The',
#   'were',
#   'over',
#   'vessels',
#   'act',
#   'and',
#   ',',
#   'the',
#   'stare',
#   ',',
#   ';',
#   'undulating',
#   '.',
#   'after',
#   'a',
#   'telling',
#   'both',
#   'upon',
#   'dashed',
#   'than',
#   'and',
#   'estate',
#   'fast',
#   'seemed',
#   ';',
#   'were',
#   'life',
#   'FOLIO',
#   'in',
#   'off',
#   'distinct',
#   'Edgewise',
#   'at',
#   'the',
#   'the',
#   'aspect',
#   'alcoves',
#   'cups',
#   'Nantucketers',
#   'the',
#   'brotherhood',
#   'the',
#   ';',
#   'from',
#   'at',
#   'appears',
#   'the',
#   ',',
#   ',',
#   'us',
#   'GLOBE',
#   'bressed',
#   'there',
#   'of',
#   'utterly',
#   'as',
#   'and',
#   'he',
#   'but',
#   'have',
#   ',',
#   'a',
#   'thought',
#   'leaned',
#   ',',
#   'it',
#   ',',
#   'that',
#   'native',
#   ',',
#   ',',
#   'tender',
#   'winter',
#   'is',
#   'hazard',
#   'he',
#   'the',
#   'the',
#   'posies',
#   'he',
#   'evening',
#   'that',
#   'soon',
#   'proceeds',
#   'definition',
#   'to',
#   'that',
#   'lint',
#   'shipped',
#   'an',
#   ';',
#   'at',
#   "'",
#   'an',
#   '-',
#   'circumstances',
#   'has',
#   'in',
#   'of',
#   ',',
#   'scenes',
#   'of',
#   ',',
#   'intervals',
#   ',',
#   'into',
#   'fishers',
#   ',',
#   ',',
#   ',',
#   'further',
#   'face',
#   ',',
#   'The',
#   'in',
#   'at',
#   'the',
#   'reading',
#   'man',
#   'perpendicularly',
#   'm',
#   'its',
#   'some',
#   'mild',
#   'time',
#   'head',
#   'goes',
#   'dashed',
#   ',',
#   'boat',
#   'creature',
#   ',',
#   'at',
#   'of',
#   'him',
#   'Post',
#   'formed',
#   'nooks',
#   'now',
#   'grin',
#   'presentment',
#   '-',
#   'stark',
#   'here',
#   'lay',
#   'God',
#   'rests',
#   'pedestrian',
#   'aye',
#   'as',
#   'his',
#   'exceed',
#   '"\'',
#   'as',
#   ',',
#   'questionings',
#   'conceit',
#   'man',
#   'one',
#   ',',
#   'purporting',
#   'out',
#   'maternal',
#   'bound',
#   'air',
#   'long',
#   'sailed',
#   'called',
#   ',',
#   ',',
#   'killed',
#   'hand',
#   'ship',
#   'own',
#   'set',
#   'with',
#   'guess',
#   'kinds',
#   'very',
#   'of',
#   ',',
#   'that',
#   'not',
#   'the',
#   'stranded',
#   'of',
#   'in',
#   'not',
#   ',',
#   'the',
#   'Nevertheless',
#   'the',
#   'chairs',
#   'the',
#   'is',
#   'insular',
#   'and',
#   'your',
#   'heads',
#   'I',
#   'abominable',
#   'nill',
#   'thirty',
#   'call',
#   'you',
#   'in',
#   'boy',
#   'DECK',
#   'bed',
#   'Down',
#   'Ever',
#   'altogether',
#   'pursuit',
#   'White',
#   'friend',
#   'whales',
#   'when',
#   'now',
#   'posture',
#   'Crying',
#   'motion',
#   'mast',
#   'the',
#   'his',
#   'and',
#   'ever',
#   'jaw',
#   'was',
#   '!',
#   'porch',
#   'poet',
#   'thing',
#   'is',
#   'crew',
#   'procuring',
#   'as',
#   'head',
#   ';',
#   'the',
#   'Yet',
#   ';',
#   'repentance',
#   ',',
#   'mine',
#   'consists',
#   'again',
#   'fell',
#   'heart',
#   'little',
#   'he',
#   'vigorously',
#   'stand',
#   ',',
#   'lurks',
#   'the',
#   ',',
#   'to',
#   ',',
#   'absent',
#   'nigh',
#   'have',
#   'of',
#   'kick',
#   'base',
#   'think',
#   'is',
#   'of',
#   'startled',
#   'gentlemanly',
#   'Starbuck',
#   'a',
#   'the',
#   'each',
#   'weal',
#   'with',
#   'of',
#   'fell',
#   'wives',
#   'after',
#   'the',
#   'charm',
#   ',',
#   'from',
#   'track',
#   'many',
#   'his',
#   'their',
#   ',',
#   'same',
#   'all',
#   'the',
#   'you',
#   'break',
#   'the',
#   'soon',
#   'calves',
#   'after',
#   'is',
#   '"\'',
#   'in',
#   'white',
#   'can',
#   'a',
#   'a',
#   'sperm',
#   'assailants',
#   'hard',
#   'feet',
#   'sea',
#   'chilly',
#   'word',
#   'of',
#   'said',
#   'enduring',
#   'yourself',
#   'now',
#   ';',
#   'this',
#   'BLACKSMITH',
#   'foreknew',
#   ',',
#   'Whale',
#   'This',
#   '.',
#   'help',
#   'Ishmael',
#   'is',
#   'awhile',
#   'hemp',
#   'the',
#   'which',
#   'of',
#   'the',
#   'say',
#   'Jonah',
#   '"',
#   'I',
#   'You',
#   'adding',
#   'commander',
#   'promising',
#   'with',
#   'old',
#   'goin',
#   '!',
#   "'",
#   'when',
#   'ship',
#   'Woebegone',
#   'possess',
#   'but',
#   'Hussey',
#   'seat',
#   'the',
#   ',',
#   'in',
#   'Fish',
#   'harpoon',
#   'leagues',
#   'suit',
#   'sharks',
#   'chapel',
#   'aye',
#   ',',
#   'out',
#   ',',
#   'on',
#   'glancing',
#   'were',
#   'aside',
#   'the',
#   'is',
#   'her',
#   'and',
#   'But',
#   'makes',
#   '-',
#   'Let',
#   'and',
#   'to',
#   'tierce',
#   ';',
#   'suffusingly',
#   'out',
#   'mark',
#   'ringed',
#   'Starbuck',
#   'in',
#   '!',
#   'deciphered',
#   'mouldings',
#   'teeth',
#   'has',
#   ',',
#   'it',
#   '?',
#   'the',
#   'of',
#   'charitable',
#   'a',
#   'all',
#   'it',
#   'somehow',
#   'AFFGHANISTAN',
#   'their',
#   'beat',
#   'would',
#   'Jonah',
#   'to',
#   'engaged',
#   'quantity',
#   'and',
#   'of',
#   'him',
#   '.',
#   'a',
#   'Near',
#   'so',
#   'deck',
#   'gallant',
#   'curiously',
#   '"--',
#   'in',
#   'saw',
#   'state',
#   'the',
#   'scrape',
#   '.',
#   'wild',
#   '.',
#   '.',
#   'a',
#   'hearties',
#   'all',
#   ';',
#   'joined',
#   'like',
#   'the',
#   'fly',
#   'gentleman',
#   'my',
#   'made',
#   'for',
#   'clue',
#   'copper',
#   'his',
#   'to',
#   'Heaven',
#   'five',
#   ',',
#   'was',
#   'chiefs',
#   '!',
#   'hunt',
#   'decoction',
#   'what',
#   'her',
#   'below',
#   'post',
#   'Partly',
#   'stranger',
#   'from',
#   'to',
#   ';',
#   'a',
#   'they',
#   'beginning',
#   "'",
#   'For',
#   ',',
#   'thrown',
#   ',',
#   'moulded',
#   'ashore',
#   'like',
#   'turned',
#   'me',
#   'want',
#   'oozy',
#   'The',
#   'mast',
#   ',',
#   'sets',
#   'warring',
#   'were',
#   ',',
#   'life',
#   'as',
#   'with',
#   'knew',
#   'by',
#   'voyages',
#   '."',
#   '?',
#   'it',
#   'of',
#   'were',
#   'vinegar',
#   'but',
#   'ordinary',
#   'clothed',
#   'the',
#   'that',
#   'deck',
#   'bastions',
#   'nappishness',
#   'that',
#   'and',
#   'the',
#   'of',
#   'plainly',
#   '.',
#   "'",
#   'then',
#   'his',
#   'against',
#   'impotent',
#   '.',
#   "'",
#   '?"--',
#   'and',
#   ';',
#   'exasperated',
#   'even',
#   'spade',
#   '!',
#   'he',
#   ',',
#   'the',
#   'more',
#   'The',
#   'might',
#   ',',
#   'captive',
#   'get',
#   '?',
#   'Prodromus',
#   'gazing',
#   ',',
#   'confines',
#   'whales',
#   'a',
#   '.',
#   ';',
#   'seems',
#   'air',
#   'thickly',
#   'flinging',
#   'Take',
#   'What',
#   'withstanding',
#   'and',
#   'ivory',
#   'then',
#   'plainly',
#   ',',
#   'I',
#   'them',
#   'lone',
#   'sometimes',
#   'in',
#   'they',
#   'boat',
#   ',',
#   'daylight',
#   'and',
#   ',',
#   ';',
#   'have',
#   ',',
#   'concerning',
#   'roasted',
#   ',',
#   'a',
#   'away',
#   'have',
#   'Perseus',
#   '--',
#   'sporty',
#   'weather',
#   'right',
#   'for',
#   'I',
#   'passage',
#   'Sherry',
#   'behind',
#   'five',
#   'MAIN',
#   'man',
#   'be',
#   '.',
#   'men',
#   'grew',
#   '.',
#   'hardly',
#   ',',
#   'down',
#   'they',
#   'illuminated',
#   'to',
#   'charcoal',
#   ',',
#   '71',
#   'distance',
#   'sailors',
#   'thawed',
#   ',',
#   'an',
#   'by',
#   'and',
#   '-',
#   'grooves',
#   'best',
#   'taste',
#   ',',
#   'might',
#   'they',
#   'times',
#   'all',
#   'Prometheus',
#   'of',
#   'yourself',
#   'it',
#   'sleepers',
#   'see',
#   'diameter',
#   'months',
#   'turning',
#   'principles',
#   'WHERE',
#   'its',
#   'outlandish',
#   'the',
#   'he',
#   'of',
#   'surf',
#   'stranger',
#   'dawn',
#   'he',
#   'many',
#   'ring',
#   'the',
#   'with',
#   ',',
#   'of',
#   'on',
#   ',',
#   'blend',
#   'from',
#   'the',
#   'sleeves',
#   'singular',
#   ',',
#   'cockpits',
#   'and',
#   'ladder',
#   'emotion',
#   ',"',
#   'them',
#   ',',
#   'strangeness',
#   'Rhenish',
#   'they',
#   ',',
#   'rescue',
#   "'",
#   'starting',
#   'life',
#   'West',
#   'Landlord',
#   'towards',
#   'an',
#   'all',
#   ',',
#   '.',
#   'in',
#   'arrives',
#   'night',
#   'events',
#   'was',
#   'Sperm',
#   'with',
#   'Don',
#   's',
#   'some',
#   'waters',
#   'exist',
#   'by',
#   'than',
#   ',',
#   'strange',
#   'another',
#   'strangeness',
#   'VERBAL',
#   'and',
#   'The',
#   'hearse',
#   ';',
#   'of',
#   'all',
#   'ye',
#   'question',
#   'time',
#   'bird',
#   'for',
#   'corresponds',
#   '.',
#   '.',
#   '.',
#   'braided',
#   'about',
#   'Adverse',
#   '-',
#   ';',
#   'all',
#   'touching',
#   'pointing',
#   's',
#   's',
#   'in',
#   'killed',
#   'great',
#   ',',
#   'marbles',
#   'The',
#   'bilious',
#   '.',
#   'wonderful',
#   'equator',
#   ',',
#   'second',
#   'as',
#   'green',
#   'Usher',
#   'one',
#   'countries',
#   'day',
#   '!',
#   'as',
#   ...],
#  ['that',
#   'be',
#   'in',
#   'the',
#   'out',
#   'and',
#   'conspicuous',
#   'his',
#   ',',
#   'corn',
#   'below',
#   'head',
#   'hangs',
#   'down',
#   'Get',
#   'for',
#   'mark',
#   'it',
#   'thinkers',
#   'fishery',
#   'hopelessly',
#   '!',
#   'seems',
#   'together',
#   'splits',
#   'One',
#   'coffins',
#   ',',
#   'that',
#   'tail',
#   'occasionally',
#   'done',
#   '.',
#   'primal',
#   'some',
#   'out',
#   'is',
#   'was',
#   'Ere',
#   'as',
#   'who',
#   'sea',
#   'and',
#   'hunter',
#   'back',
#   "'",
#   'much',
#   'spotted',
#   'otherwise',
#   'question',
#   'he',
#   'with',
#   'springs',
#   'without',
#   '.',
#   'thus',
#   '!"',
#   'with',
#   'small',
#   'so',
#   'well',
#   'half',
#   ',',
#   'modelled',
#   'its',
#   'following',
#   'can',
#   'that',
#   'all',
#   'leading',
#   'concluded',
#   'timber',
#   'raving',
#   'the',
#   'must',
#   'been',
#   'as',
#   'that',
#   'a',
#   'point',
#   'many',
#   'planets',
#   'supper',
#   'three',
#   'is',
#   'tried',
#   'have',
#   'stowed',
#   ',',
#   'own',
#   'planted',
#   'lay',
#   ',',
#   ',--',
#   'over',
#   'I',
#   'bread',
#   'could',
#   'nurse',
#   'joyful',
#   'always',
#   'Adieu',
#   'all',
#   'least',
#   'of',
#   'to',
#   'And',
#   'report',
#   'SETH',
#   'I',
#   'unforgiven',
#   'from',
#   'Whale',
#   'were',
#   '!"',
#   'on',
#   'piety',
#   '-',
#   'death',
#   'cried',
#   'been',
#   'the',
#   '"',
#   'motion',
#   'remarkable',
#   'the',
#   'all',
#   'could',
#   'the',
#   'darted',
#   'myself',
#   'of',
#   'III',
#   'heads',
#   'all',
#   'plank',
#   'mate',
#   ',"',
#   'these',
#   'he',
#   'a',
#   'be',
#   'be',
#   'wails',
#   'it',
#   'go',
#   '!"',
#   'running',
#   ',',
#   'had',
#   ',',
#   'themselves',
#   '"',
#   'the',
#   'to',
#   'native',
#   'record',
#   'diminished',
#   'some',
#   'On',
#   'I',
#   'midnight',
#   'looking',
#   'towards',
#   'now',
#   ',',
#   ',',
#   "'",
#   'he',
#   'where',
#   'against',
#   ',',
#   'since',
#   ',',
#   'seen',
#   'head',
#   ',',
#   'the',
#   'on',
#   '--',
#   'for',
#   'a',
#   'I',
#   'in',
#   'within',
#   'he',
#   'that',
#   'in',
#   'rope',
#   'the',
#   'loss',
#   'at',
#   'cells',
#   'sperm',
#   'aught',
#   'sorrowful',
#   'always',
#   'of',
#   'tis',
#   'private',
#   'compass',
#   'what',
#   ',',
#   "'",
#   'limit',
#   'the',
#   'staggering',
#   'great',
#   'a',
#   'longer',
#   'TO',
#   'were',
#   '.',
#   'becomes',
#   'Rogers',
#   'and',
#   '.',
#   'would',
#   'the',
#   'or',
#   'pursuit',
#   'to',
#   'from',
#   'shadow',
#   'sea',
#   'it',
#   'best',
#   '.',
#   '.',
#   'over',
#   'in',
#   'base',
#   'Ship',
#   'if',
#   'patience',
#   'devoutly',
#   'and',
#   'more',
#   'being',
#   'from',
#   'Jeroboam',
#   'eyes',
#   '.',
#   ',',
#   'little',
#   'it',
#   'it',
#   'together',
#   'the',
#   'their',
#   'believe',
#   'dangerous',
#   'up',
#   'to',
#   'and',
#   'to',
#   'by',
#   's',
#   'curled',
#   'lads',
#   'particular',
#   '!"',
#   'me',
#   'inquiry',
#   'let',
#   'original',
#   ',',
#   ';',
#   'of',
#   'bulk',
#   'scolloped',
#   'boats',
#   'without',
#   'anywhere',
#   ',',
#   'me',
#   'Holy',
#   'when',
#   'crammed',
#   'No',
#   'welded',
#   ',',
#   'their',
#   'exterior',
#   'Moby',
#   ',',
#   'by',
#   'of',
#   'Boston',
#   'the',
#   'come',
#   'you',
#   'a',
#   'you',
#   'it',
#   'while',
#   'rituals',
#   'In',
#   'they',
#   'made',
#   'boat',
#   'mistaking',
#   'deny',
#   'as',
#   'the',
#   'thought',
#   'which',
#   '-',
#   'West',
#   '"\'',
#   'the',
#   ',',
#   'of',
#   'purpose',
#   'in',
#   'Tower',
#   'ship',
#   '"',
#   'such',
#   'soon',
#   'tail',
#   'moment',
#   'indolent',
#   'agent',
#   ',',
#   'battering',
#   'put',
#   'the',
#   'I',
#   '.',
#   ',',
#   'weather',
#   '!',
#   'with',
#   'the',
#   '.',
#   'and',
#   'the',
#   'into',
#   'churning',
#   'eagerly',
#   ',',
#   'But',
#   'they',
#   'other',
#   'whales',
#   'passing',
#   'you',
#   'of',
#   'sailed',
#   'whale',
#   'were',
#   'to',
#   'the',
#   'prodigious',
#   'a',
#   '."',
#   'Sail',
#   'days',
#   'from',
#   'of',
#   'parents',
#   'where',
#   'whale',
#   'set',
#   ',',
#   'them',
#   ',',
#   'heeling',
#   'hereabouts',
#   'whaling',
#   ',',
#   's',
#   'much',
#   'same',
#   'Nantucket',
#   'the',
#   'that',
#   ',',
#   ',',
#   'the',
#   'ye',
#   'the',
#   'regarded',
#   ',',
#   'CHAPTER',
#   'on',
#   'Horn',
#   ',',
#   'of',
#   'unfathomably',
#   'particularly',
#   'as',
#   ',',
#   'to',
#   'one',
#   'him',
#   'in',
#   'the',
#   'aside',
#   'still',
#   'to',
#   'borne',
#   ',',
#   'For',
#   'it',
#   'docks',
#   'folds',
#   'pumps',
#   'you',
#   ',',
#   'sideboard',
#   'came',
#   'and',
#   'foam',
#   'burning',
#   'Standing',
#   'men',
#   'this',
#   'breeze',
#   'is',
#   'each',
#   'with',
#   ',',
#   'them',
#   ',',
#   'Platonic',
#   'these',
#   'its',
#   'heads',
#   'its',
#   'inventor',
#   'is',
#   'ivory',
#   '.',
#   'exhibit',
#   ',',
#   'and',
#   'and',
#   'before',
#   'come',
#   'audacity',
#   'base',
#   'soft',
#   'down',
#   'bright',
#   'low',
#   ',',
#   'select',
#   'sublime',
#   'which',
#   'have',
#   'no',
#   'give',
#   'the',
#   'the',
#   'has',
#   'and',
#   'a',
#   'lance',
#   'a',
#   'only',
#   'Lakeman',
#   'philosophers',
#   'the',
#   'vesture',
#   'at',
#   'rumbled',
#   "'",
#   'yet',
#   'large',
#   ',',
#   'deepest',
#   ',',
#   'the',
#   'Two',
#   'to',
#   'marked',
#   'few',
#   'caw',
#   'them',
#   'there',
#   'that',
#   'gladness',
#   'the',
#   'could',
#   'whale',
#   'of',
#   'on',
#   'as',
#   "'",
#   'make',
#   'mast',
#   's',
#   'interruptions',
#   'any',
#   'a',
#   'hands',
#   'presents',
#   'telescope',
#   'not',
#   'the',
#   'The',
#   'waters',
#   'port',
#   'Dick',
#   'sometimes',
#   'incommunicable',
#   'ship',
#   'Sebastian',
#   'And',
#   'stove',
#   'I',
#   '.',
#   'moment',
#   'have',
#   'is',
#   'for',
#   'This',
#   'was',
#   'far',
#   'with',
#   'mout',
#   '.',
#   'allusion',
#   ',',
#   'however',
#   'so',
#   'I',
#   'the',
#   'the',
#   'of',
#   'turns',
#   'to',
#   'Christendom',
#   'its',
#   'new',
#   'have',
#   'fifty',
#   'have',
#   'ago',
#   'divine',
#   'Old',
#   'reserved',
#   ';',
#   'But',
#   'with',
#   '-',
#   'a',
#   'trip',
#   '.',
#   'not',
#   'rod',
#   '.',
#   'things',
#   'an',
#   'Obed',
#   'it',
#   'we',
#   'stands',
#   'spring',
#   'of',
#   'of',
#   'ye',
#   'tongs',
#   '-',
#   'Well',
#   '?',
#   'extra',
#   'and',
#   'books',
#   'to',
#   'mast',
#   'being',
#   ',',
#   'those',
#   'would',
#   'and',
#   'in',
#   'anything',
#   'the',
#   'rattling',
#   '!--',
#   'Northern',
#   'I',
#   'In',
#   'winds',
#   'his',
#   'of',
#   ',',
#   'after',
#   's',
#   'the',
#   'all',
#   'thing',
#   'of',
#   'or',
#   'solid',
#   'whole',
#   'said',
#   'we',
#   'of',
#   'tossed',
#   ',',
#   'its',
#   'betokened',
#   'him',
#   'in',
#   'the',
#   'plasters',
#   'quiet',
#   'rate',
#   'learned',
#   'touch',
#   'firm',
#   'uncompromisedness',
#   'Stubb',
#   'a',
#   '.',
#   'preposterous',
#   'ship',
#   'better',
#   'and',
#   'his',
#   'sea',
#   'larger',
#   ',',
#   'pursuit',
#   ',',
#   'little',
#   ':--',
#   'matter',
#   'treated',
#   'of',
#   'This',
#   'Radney',
#   'the',
#   'supported',
#   'bare',
#   'whale',
#   'a',
#   'old',
#   'brook',
#   'stripped',
#   'Moby',
#   'as',
#   'a',
#   'twisting',
#   'have',
#   'Ahab',
#   '(',
#   'Colonies',
#   'is',
#   ',',
#   'the',
#   'so',
#   'so',
#   'over',
#   'craft',
#   'leaky',
#   'of',
#   'this',
#   'straight',
#   'of',
#   ',',
#   'peculiar',
#   'hopeless',
#   'you',
#   'decks',
#   'twiske',
#   'If',
#   'tossed',
#   'of',
#   'rooms',
#   'attraction',
#   ';',
#   '.',
#   'stagger',
#   'out',
#   '.',
#   'thought',
#   'then',
#   '"',
#   'of',
#   'only',
#   'thee',
#   'till',
#   'flung',
#   'to',
#   'have',
#   'but',
#   'mass',
#   ';',
#   'with',
#   'bench',
#   'most',
#   'all',
#   'other',
#   'was',
#   'in',
#   ',',
#   'be',
#   'e',
#   'first',
#   '.',
#   'to',
#   ',',
#   'There',
#   'indeed',
#   'on',
#   'in',
#   'the',
#   'had',
#   'it',
#   'proper',
#   'parted',
#   'two',
#   'while',
#   'will',
#   'for',
#   'Dough',
#   'to',
#   'bore',
#   'young',
#   'he',
#   'me',
#   'Pequod',
#   'flirted',
#   'man',
#   'from',
#   'vague',
#   'the',
#   'm',
#   'be',
#   'thought',
#   'fogs',
#   'borne',
#   'lowered',
#   'now',
#   'coiled',
#   'is',
#   'S',
#   'rig',
#   'such',
#   'have',
#   'that',
#   'from',
#   ';',
#   'us',
#   ',',
#   'where',
#   'the',
#   '.',
#   'water',
#   'Who',
#   'I',
#   'a',
#   'active',
#   'for',
#   'word',
#   'beyond',
#   ',',
#   'could',
#   'ascended',
#   'none',
#   'were',
#   'are',
#   'innocent',
#   ',',
#   'transformed',
#   'that',
#   'Fish',
#   'tackle',
#   'life',
#   'Gabriel',
#   'the',
#   'hanging',
#   'Meantime',
#   'generally',
#   'the',
#   'his',
#   'barrel',
#   "'",
#   'to',
#   'the',
#   '32',
#   'deck',
#   'rim',
#   ',',
#   'mind',
#   'and',
#   'all',
#   'always',
#   'some',
#   'was',
#   'command',
#   'Ahab',
#   'that',
#   'period',
#   ',',
#   'side',
#   'intolerably',
#   'yea',
#   'your',
#   'the',
#   'boat',
#   ',',
#   'there',
#   'the',
#   'clinging',
#   'would',
#   'men',
#   '!',
#   'unbegotten',
#   'not',
#   'has',
#   ',',
#   'considering',
#   'ever',
#   ',',
#   'in',
#   'at',
#   'a',
#   'is',
#   'the',
#   'Through',
#   'ever',
#   'it',
#   'made',
#   'with',
#   '"',
# ...
#   ',',
#   'him',
#   'I',
#   'a',
#   'four',
#   ',',
#   'fan',
#   'aghast',
#   'the',
#   'about',
#   'boys',
#   'all',
#   'eventually',
#   'a',
#   'with',
#   'have',
#   'boat',
#   'worsted',
#   'gods',
#   'god',
#   'and',
#   'I',
#   'was',
#   'questions',
#   'about',
#   'proceedings',
#   'vest',
#   'authorities',
#   '.',
#   '.',
#   'be',
#   'the',
#   'this',
#   'sweeping',
#   'the',
#   '.',
#   'recorded',
#   'soon',
#   'forehead',
#   'rather',
#   'for',
#   'stand',
#   'And',
#   'almost',
#   'so',
#   'Aloft',
#   'calling',
#   'great',
#   'girls',
#   'years',
#   'like',
#   'in',
#   ':',
#   'under',
#   '?"',
#   ';',
#   'mouth',
#   'crossed',
#   'nevertheless',
#   'hand',
#   'that',
#   'explored',
#   ',',
#   'my',
#   'on',
#   'whale',
#   'and',
#   'similar',
#   ',',
#   'assured',
#   'to',
#   'side',
#   ',',
#   'hailed',
#   'curious',
#   'his',
#   'cutting',
#   'that',
#   'of',
#   'tall',
#   'that',
#   'bread',
#   'often',
#   'no',
#   'pile',
#   'quickly',
#   'towards',
#   'brush',
#   'that',
#   'the',
#   'of',
#   'it',
#   'and',
#   '-',
#   'of',
#   'but',
#   ',',
#   'the',
#   'fanciful',
#   'em',
#   'sun',
#   'and',
#   'dry',
#   '-',
#   'With',
#   'A',
#   'dipping',
#   ',',
#   'I',
#   ',',
#   'it',
#   'one',
#   'there',
#   'mouts',
#   'route',
#   'three',
#   'and',
#   'be',
#   'changed',
#   'both',
#   'shearing',
#   'a',
#   ',',
#   'parts',
#   'Nantucketer',
#   'and',
#   'me',
#   'Sperm',
#   'differs',
#   ',',
#   'of',
#   'long',
#   'now',
#   'fellow',
#   'his',
#   'his',
#   'which',
#   'generally',
#   'Quaker',
#   'have',
#   'gentleman',
#   'it',
#   'power',
#   'the',
#   'and',
#   'in',
#   '--',
#   'a',
#   'piercing',
#   'that',
#   'wilful',
#   'my',
#   'BOOK',
#   'half',
#   '.',
#   'at',
#   'vigorous',
#   'in',
#   'green',
#   'to',
#   'concert',
#   'here',
#   'mention',
#   'overhead',
#   'no',
#   'that',
#   'drawn',
#   'and',
#   '--',
#   'part',
#   ',',
#   'For',
#   'America',
#   'steel',
#   'and',
#   'a',
#   'he',
#   'greatest',
#   'surtout',
#   'shouldering',
#   'the',
#   ',--',
#   '.',
#   'I',
#   'Sibbald',
#   'shape',
#   ',',
#   ',',
#   'head',
#   'Byward',
#   'and',
#   'the',
#   'certain',
#   'taken',
#   'word',
#   'from',
#   'the',
#   'out',
#   'remarking',
#   'whale',
#   ';',
#   'without',
#   '-',
#   'well',
#   'sperm',
#   'on',
#   'and',
#   'Niger',
#   'must',
#   'to',
#   'body',
#   'ain',
#   'icicles',
#   'this',
#   'her',
#   'still',
#   'Thank',
#   'old',
#   'undue',
#   'A',
#   'was',
#   'himself',
#   'sideways',
#   'never',
#   'subterraneous',
#   'fast',
#   'Ahab',
#   '.',
#   'was',
#   '.',
#   'that',
#   'of',
#   'a',
#   'upon',
#   'his',
#   'that',
#   'a',
#   'and',
#   '.',
#   'move',
#   'being',
#   'betrayed',
#   'fight',
#   'before',
#   'have',
#   'all',
#   'in',
#   '-',
#   'would',
#   'when',
#   'I',
#   'of',
#   'every',
#   'and',
#   'seems',
#   'were',
#   'is',
#   'a',
#   'away',
#   'importance',
#   'over',
#   'often',
#   'such',
#   'is',
#   'the',
#   'the',
#   '."',
#   'congenialities',
#   '.',
#   'her',
#   'to',
#   'then',
#   'for',
#   'simultaneously',
#   'Vineyard',
#   'uncommon',
#   'or',
#   'through',
#   'ocean',
#   ';',
#   'with',
#   'by',
#   'it',
#   'In',
#   'of',
#   'at',
#   'behold',
#   'canoes',
#   'three',
#   'in',
#   'side',
#   'have',
#   'holding',
#   'circumstance',
#   'strain',
#   'well',
#   'Learning',
#   'King',
#   'more',
#   ',',
#   'wake',
#   'landed',
#   'doors',
#   'in',
#   'Avast',
#   'master',
#   'as',
#   "'",
#   'coupled',
#   'unrestingly',
#   'Stubb',
#   'promontory',
#   'Captain',
#   'the',
#   'and',
#   '"',
#   'and',
#   'and',
#   'of',
#   'found',
#   'to',
#   'feeder',
#   '.',
#   'nailed',
#   'all',
#   'away',
#   ',',
#   'chorus',
#   'the',
#   'for',
#   'eddying',
#   '?"',
#   'But',
#   'especially',
#   'who',
#   'striking',
#   'long',
#   'the',
#   'it',
#   'God',
#   ',',
#   'The',
#   'quailed',
#   'my',
#   'bitts',
#   'he',
#   ',',
#   'out',
#   'provided',
#   'high',
#   'as',
#   'other',
#   'wildly',
#   'the',
#   'the',
#   'in',
#   '.',
#   'to',
#   '--',
#   'isinglass',
#   'costly',
#   'be',
#   'Atlantic',
#   'the',
#   'with',
#   'to',
#   'moment',
#   'a',
#   'and',
#   'great',
#   'to',
#   'easy',
#   'an',
#   'Tashtego',
#   'You',
#   ',',
#   'inflicted',
#   'had',
#   'It',
#   'again',
#   'higher',
#   'He',
#   'all',
#   '"',
#   '.',
#   'two',
#   'that',
#   'because',
#   'more',
#   'was',
#   'joints',
#   'the',
#   'he',
#   'and',
#   'that',
#   'man',
#   'foundations',
#   'this',
#   'of',
#   '?"',
#   'all',
#   'start',
#   'who',
#   'fishermen',
#   'head',
#   'therefore',
#   'all',
#   ',',
#   'filled',
#   'smoking',
#   'gave',
#   'the',
#   'had',
#   'then',
#   'exhale',
#   'strange',
#   ',',
#   'the',
#   'is',
#   ',',
#   'Main',
#   'then',
#   'the',
#   's',
#   'the',
#   'of',
#   '-',
#   'cut',
#   'tails',
#   'surrounded',
#   'is',
#   'vessel',
#   'to',
#   'the',
#   ',',
#   ',',
#   'Thus',
#   'I',
#   'treats',
#   'their',
#   'not',
#   'it',
#   's',
#   'were',
#   'it',
#   'chewed',
#   'must',
#   'irrespective',
#   'it',
#   'There',
#   'had',
#   'Rocks',
#   'Miles',
#   'no',
#   'hold',
#   ',',
#   'terrific',
#   'and',
#   'or',
#   'surface',
#   '.',
#   'CHAPTER',
#   '?',
#   'prophet',
#   'species',
#   '-',
#   'long',
#   'jaws',
#   'grooves',
#   'and',
#   'some',
#   ',',
#   'the',
#   'What',
#   'humbug',
#   'him',
#   'wedded',
#   'somehow',
#   'at',
#   'squaring',
#   'board',
#   'canoes',
#   'John',
#   'higher',
#   ',',
#   'ten',
#   'loomed',
#   'placed',
#   'Delightful',
#   'of',
#   'the',
#   'whale',
#   '."',
#   'the',
#   'leaving',
#   'being',
#   'upon',
#   'for',
#   'came',
#   'voice',
#   'good',
#   'and',
#   'august',
#   ',',
#   'coat',
#   'and',
#   'will',
#   'these',
#   'up',
#   'still',
#   'ones',
#   'of',
#   'A',
#   'up',
#   'was',
#   'one',
#   ',',
#   'was',
#   'Palace',
#   'that',
#   'chase',
#   'were',
#   'that',
#   'any',
#   'into',
#   '--',
#   'whale',
#   'is',
#   'Oh',
#   'White',
#   'by',
#   'yonder',
#   'all',
#   'was',
#   'reach',
#   'now',
#   'agency',
#   '-',
#   've',
#   'in',
#   'up',
#   'TWO',
#   'near',
#   '.',
#   ',',
#   'show',
#   'its',
#   'Virtue',
#   'as',
#   'to',
#   'a',
#   '!',
#   'the',
#   'conclude',
#   ',',
#   'through',
#   ',',
#   'and',
#   'be',
#   'all',
#   ';',
#   'do',
#   'go',
#   ',',
#   'flakes',
#   '-',
#   '(',
#   'So',
#   'think',
#   'some',
#   'him',
#   'how',
#   ',',
#   'had',
#   'circumstances',
#   'told',
#   'I',
#   'heaps',
#   'all',
#   'them',
#   'he',
#   'the',
#   'told',
#   'aloft',
#   'stabs',
#   'forehead',
#   ',',
#   'all',
#   'Nantucket',
#   ',',
#   ',',
#   ';',
#   'it',
#   'application',
#   '.',
#   'baleful',
#   '.',
#   'was',
#   'over',
#   '-',
#   'and',
#   'like',
#   'hemp',
#   'his',
#   'for',
#   'About',
#   'of',
#   'far',
#   'did',
#   ',--',
#   'oil',
#   'and',
#   'of',
#   'a',
#   'boat',
#   'handled',
#   ',',
#   'middle',
#   'was',
#   'more',
#   '"',
#   'On',
#   'then',
#   ...],
#  ['your',
#   '--',
#   'The',
#   'Hast',
#   'him',
#   ',',
#   'of',
#   'one',
#   'pause',
#   'devilish',
#   'a',
#   'the',
#   'we',
#   'then',
#   'morning',
#   'uncomfortable',
#   '--',
#   'us',
#   ',',
#   'knowest',
#   'towards',
#   'preaching',
#   'or',
#   'jig',
#   'He',
#   'command',
#   'the',
#   'account',
#   'flailed',
#   'Ahab',
#   ',',
#   '-',
#   ',',
#   'his',
#   'he',
#   'a',
#   'insignificant',
#   '-',
#   'just',
#   'in',
#   'to',
#   'civil',
#   'sweep',
#   'in',
#   's',
#   'my',
#   ',',
#   'RETAKING',
#   'one',
#   'comes',
#   'the',
#   ',',
#   'exalted',
#   'one',
#   'board',
#   'musty',
#   'of',
#   'it',
#   'this',
#   'and',
#   'this',
#   'but',
#   'redness',
#   'lances',
#   '(',
#   'as',
#   's',
#   'said',
#   's',
#   'about',
#   'He',
#   'before',
#   ';',
#   'rolled',
#   'Lake',
#   'for',
#   'at',
#   'and',
#   'contents',
#   'to',
#   'a',
#   '.',
#   ',',
#   '.',
#   'violence',
#   ';',
#   'Sea',
#   'Englishman',
#   ',',
#   'sanity',
#   'generous',
#   'and',
#   'special',
#   '!',
#   'of',
#   'its',
#   'touchy',
#   ',',
#   'short',
#   'teeth',
#   'upon',
#   'in',
#   'of',
#   'White',
#   ',',
#   'of',
#   'something',
#   'invested',
#   'such',
#   'of',
#   'as',
#   'his',
#   'his',
#   'all',
#   'Blinding',
#   'greatness',
#   'gold',
#   'rallied',
#   'his',
#   'it',
#   'said',
#   'all',
#   'carved',
#   'here',
#   'rest',
#   'of',
#   'the',
#   'mountainous',
#   'used',
#   'may',
#   'oaken',
#   'white',
#   'in',
#   'well',
#   'mean',
#   '--',
#   'comfort',
#   'far',
#   "'",
#   'in',
#   'own',
#   'drugged',
#   'done',
#   'I',
#   'worn',
#   'Pacific',
#   'islanders',
#   'the',
#   'wails',
#   'MENDING',
#   'against',
#   'curds',
#   'seems',
#   '?',
#   'the',
#   'gone',
#   'out',
#   'to',
#   'all',
#   'there',
#   'some',
#   '(',
#   ';',
#   'the',
#   'and',
#   'abroad',
#   'And',
#   'to',
#   'easy',
#   'began',
#   'large',
#   'moment',
#   'his',
#   'it',
#   'so',
#   'soul',
#   's',
#   'chocks',
#   'most',
#   'as',
#   'broken',
#   'especially',
#   'short',
#   'Moby',
#   'of',
#   '.',
#   'he',
#   'book',
#   ',',
#   'or',
#   'mere',
#   'air',
#   '?"',
#   '?"',
#   ',',
#   'deeper',
#   'my',
#   'and',
#   'over',
#   'across',
#   'of',
#   'a',
#   'of',
#   'more',
#   'here',
#   ',',
#   '--',
#   'moment',
#   'circumference',
#   '.',
#   'and',
#   's',
#   'Tartar',
#   'that',
#   'seated',
#   'with',
#   'every',
#   'his',
#   ',',
#   'with',
#   'for',
#   'open',
#   'boats',
#   'Stubb',
#   'water',
#   'wouldn',
#   'a',
#   'have',
#   'whetstone',
#   ',',
#   'again',
#   'Mapple',
#   'a',
#   'owing',
#   'my',
#   'into',
#   'many',
#   'lift',
#   'under',
#   ',',
#   'the',
#   "'",
#   "'",
#   'before',
#   'and',
#   'the',
#   ';',
#   'main',
#   'the',
#   'old',
#   '.',
#   'Peering',
#   'the',
#   'the',
#   'day',
#   'him',
#   'upon',
#   '!',
#   ',',
#   '-',
#   'and',
#   'Leviathan',
#   '?',
#   '-',
#   'him',
#   '.',
#   'wife',
#   'to',
#   '-',
#   'yet',
#   'ocean',
#   ',',
#   'am',
#   ',',
#   'for',
#   'have',
#   'And',
#   'it',
#   'Champollion',
#   'inelegant',
#   'said',
#   'him',
#   ';',
#   'technically',
#   'the',
#   'deck',
#   'indestructible',
#   'raised',
#   'of',
#   'of',
#   'calves',
#   'the',
#   'well',
#   ',',
#   'the',
#   'all',
#   'by',
#   'of',
#   ',',
#   'and',
#   'exclaimed',
#   'world',
#   'and',
#   'his',
#   'now',
#   'TAMBOURINE',
#   'expanse',
#   'or',
#   '.',
#   'any',
#   'articles',
#   'sail',
#   'housekeepers',
#   'overladen',
#   ',',
#   'sternward',
#   'diligence',
#   'eye',
#   'of',
#   "'",
#   'the',
#   's',
#   'of',
#   'lead',
#   'one',
#   'heedfulness',
#   ',',
#   'me',
#   'lance',
#   'long',
#   'this',
#   'sail',
#   '-',
#   'cruise',
#   'as',
#   ',',
#   'I',
#   ',',
#   'limbs',
#   'animal',
#   'nor',
#   'sound',
#   'a',
#   'face',
#   'speak',
#   'while',
#   'Banks',
#   'his',
#   'of',
#   'unknown',
#   'mouth',
#   'can',
#   'that',
#   'other',
#   'Commodore',
#   's',
#   'image',
#   'thereupon',
#   'him',
#   'AND',
#   'there',
#   'thee',
#   'minute',
#   'have',
#   'king',
#   'that',
#   ',',
#   'him',
#   'Ahab',
#   's',
#   'looking',
#   'an',
#   'dashes',
#   'and',
#   'downwards',
#   'exciting',
#   'a',
#   'his',
#   'the',
#   'am',
#   'ye',
#   'ivory',
#   'harpoon',
#   ',',
#   'Sub',
#   'that',
#   'to',
#   'in',
#   'little',
#   'sparkling',
#   'and',
#   'out',
#   'twin',
#   'of',
#   "'",
#   'Aries',
#   'and',
#   'met',
#   'boats',
#   'of',
#   'like',
#   'thy',
#   'asked',
#   'whales',
#   'something',
#   'air',
#   'a',
#   'swept',
#   'the',
#   'a',
#   'rope',
#   'that',
#   'into',
#   'By',
#   '.',
#   'unknown',
#   'whaleman',
#   'needles',
#   'a',
#   '-',
#   'of',
#   'much',
#   'stretch',
#   'resolved',
#   ';',
#   'are',
#   '.',
#   'string',
#   'which',
#   'to',
#   'st',
#   'circle',
#   'friendliness',
#   'way',
#   'you',
#   ".'",
#   'I',
#   'different',
#   'like',
#   'much',
#   'waters',
#   '-',
#   'Right',
#   'discovery',
#   'itself',
#   'encircling',
#   ';',
#   'fight',
#   'friend',
#   'spirits',
#   'deserve',
#   ',',
#   'kink',
#   'ship',
#   'the',
#   'and',
#   'the',
#   'of',
#   'right',
#   'me',
#   'if',
#   'cannot',
#   'Do',
#   'keener',
#   'that',
#   'shall',
#   'out',
#   ',',
#   'all',
#   'terror',
#   ',',
#   'Pharaoh',
#   '"',
#   'through',
#   'of',
#   'as',
#   'Clear',
#   'mottled',
#   'over',
#   'too',
#   'by',
#   'back',
#   'moment',
#   'must',
#   '--',
#   'mug',
#   'and',
#   'mortal',
#   'capture',
#   ',',
#   'forth',
#   'seen',
#   'four',
#   'every',
#   'has',
#   'all',
#   'your',
#   ',',
#   ';',
#   'on',
#   'off',
#   'and',
#   'unmanufactured',
#   'northern',
#   'swim',
#   'it',
#   'seventy',
#   'of',
#   'you',
#   'subdued',
#   'and',
#   'like',
#   'while',
#   'in',
#   'the',
#   ',',
#   'in',
#   'noteworthy',
#   'seals',
#   'Chief',
#   ';',
#   ',',
#   'no',
#   'length',
#   '!',
#   ',',
#   'at',
#   'it',
#   'Typhoon',
#   'seem',
#   '-',
#   'but',
#   'the',
#   ';',
#   ',',
#   'house',
#   'bell',
#   ',',
#   's',
#   'The',
#   'ye',
#   'God',
#   'was',
#   'in',
#   'at',
#   '"',
#   'he',
#   'calling',
#   'you',
#   'with',
#   "'",
#   'First',
#   'of',
#   'those',
#   'the',
#   'lie',
#   '.',
#   'now',
#   'any',
#   'he',
#   'kills',
#   'home',
#   'of',
#   'bed',
#   'the',
#   'they',
#   's',
#   'the',
#   'of',
#   'had',
#   'sailor',
#   'say',
#   'it',
#   'It',
#   'Protestant',
#   'their',
#   ',',
#   'their',
#   'the',
#   'azure',
#   'so',
#   'him',
#   'Spouter',
#   ';',
#   ',',
#   'quivering',
#   'What',
#   ',',
#   ',',
#   'death',
#   'Such',
#   '!',
#   'sucked',
#   'too',
#   'much',
#   'gigantic',
#   'species',
#   'he',
#   '--',
#   'thing',
#   'assert',
#   'of',
#   'I',
#   'indifferent',
#   'of',
#   'weigh',
#   'was',
#   'that',
#   'forecastle',
#   ')',
#   'those',
#   'deep',
#   'of',
#   'But',
#   'jeopardy',
#   'over',
#   'completely',
#   'or',
#   'other',
#   'the',
#   'begun',
#   'mortar',
#   'and',
#   'life',
#   'the',
#   'next',
#   'shapes',
#   'the',
#   ',',
#   'it',
#   ',',
#   'White',
#   'proportions',
#   'indeed',
#   'five',
#   "'",
#   '.',
#   '!--',
#   'trace',
#   'harpoon',
#   'cannot',
#   ',',
#   'uninhabited',
#   'it',
#   'they',
#   'find',
#   'head',
#   'intolerable',
#   'portentousness',
#   'upbraidings',
#   ';',
#   'coat',
#   'arisen',
#   's',
#   'for',
#   'd',
#   "'",
#   'waist',
#   'or',
#   ',',
#   'carrying',
#   'Queequeg',
#   "'",
#   ',',
#   'Thirty',
#   'he',
#   'of',
#   ',',
#   'of',
#   'there',
#   'quietude',
#   'his',
#   'with',
#   'Captain',
#   '!',
#   'a',
#   'boat',
#   'sea',
#   'pyramid',
#   'sail',
#   'There',
#   'it',
#   'slanderin',
#   'I',
#   'innermost',
#   'him',
#   'basement',
#   'laying',
#   '.',
#   'The',
#   'seldom',
#   'Pagan',
#   'then',
#   'followed',
#   'aground',
#   'the',
#   'the',
#   'the',
#   'flavor',
#   'Anatomist',
#   'Pequod',
#   'of',
#   ';',
#   'I',
#   'miracle',
#   '?',
#   'a',
#   'against',
#   '?"',
#   'in',
#   'don',
#   'man',
#   'thoughts',
#   'of',
#   'ye',
#   'vessels',
#   'permitted',
#   'pious',
#   'turned',
#   'Virginia',
#   'fugitive',
#   ',',
#   'were',
#   'part',
#   'never',
#   'greater',
#   'measure',
#   'hole',
#   'not',
#   'As',
#   'see',
#   'particular',
#   'pass',
#   'to',
#   'doing',
#   'were',
#   'so',
#   '-',
#   ',',
#   ';',
#   'over',
#   ',',
#   'his',
#   'try',
#   '.',
#   'quick',
#   'the',
#   'endless',
#   'sit',
#   '.',
#   'some',
#   'he',
#   'strands',
#   'any',
#   'the',
#   'stagger',
#   'hand',
#   'fire',
#   'Coffin',
#   'sailing',
#   'that',
#   '!',
#   'came',
#   'supplants',
#   'he',
#   'chance',
#   'swim',
#   'severe',
#   '!"',
#   ',',
#   'water',
#   'prouder',
#   'this',
#   'of',
#   'together',
#   'Nothing',
#   'under',
#   'Sperm',
#   'over',
#   'the',
#   'one',
#   'the',
#   'name',
#   '."',
#   'D',
#   'the',
#   ',',
#   'the',
#   'him',
#   '"',
#   'outs',
#   'retain',
#   '.',
#   '-',
#   'speed',
#   'a',
#   'the',
#   'even',
#   'a',
#   'Away',
#   ',',
#   'I',
#   'valiantly',
#   'a',
#   'festivities',
#   'a',
#   'and',
#   'exceedingly',
#   'I',
#   'devils',
#   'He',
#   ',',
#   'but',
#   'calamity',
#   'ship',
#   'the',
#   'in',
#   ',',
#   'New',
#   'the',
#   'we',
#   '.',
#   'upon',
#   ',',
#   'mottled',
#   ',',
#   ',',
#   'to',
#   ',',
#   'in',
#   ',',
#   'roar',
#   'without',
#   'will',
#   'up',
#   'smitten',
#   'it',
#   'like',
#   ',',
#   'a',
#   'had',
#   'have',
#   '.',
#   'called',
#   'intervals',
#   'but',
#   '!',
#   ',"',
#   'some',
#   'twenty',
#   'same',
#   'it',
#   '-',
#   'Ah',
#   ',',
#   'strictest',
#   'occupies',
#   'an',
#   '?"',
#   'with',
#   'and',
#   'hands',
#   'lines',
#   'Nor',
#   ',',
#   ',',
#   'me',
#   'that',
#   'sufficiently',
#   'by',
#   'for',
#   '.',
#   'school',
#   'one',
#   'yet',
#   'in',
#   'side',
#   '"',
#   'and',
#   'expound',
#   ';',
#   'meanings',
#   'in',
#   ";'",
#   'This',
#   'fancy',
#   '!"',
#   'more',
#   ',',
#   'nuts',
#   'to',
#   ',',
#   'in',
#   'Forced',
#   'came',
#   'use',
#   'not',
#   'with',
#   'that',
#   'water',
#   'hundredth',
#   'yet',
#   'and',
#   ',',
#   'knife',
#   'other',
#   '!',
#   ',',
#   'busy',
#   ',',
#   'it',
#   'Washington',
#   'any',
#   'the',
#   'If',
#   'callest',
#   'the',
#   'sails',
#   'so',
#   'that',
#   'dabs',
#   'Nantucket',
#   'withstand',
#   'language',
#   'was',
#   'me',
#   'on',
#   'in',
#   'only',
#   'to',
#   'round',
#   'the',
#   'up',
#   'Italian',
#   'his',
#   'wrist',
#   'require',
#   'spiracle',
#   'back',
#   'me',
#   'prodigy',
#   'shot',
#   'long',
#   'of',
#   'that',
#   'up',
#   'spend',
#   '.',
#   'the',
#   'a',
#   'be',
#   ',',
#   ';',
#   'you',
#   'a',
#   '.',
#   'of',
#   'of',
#   'some',
#   'their',
#   'weathering',
#   'a',
#   'this',
#   'slice',
#   'GAM',
#   'No',
#   '!',
#   'sob',
#   'extant',
#   'want',
#   'in',
#   ';',
#   'attend',
#   'mortal',
#   '."',
#   'There',
#   'in',
#   '-',
#   'if',
#   'faded',
#   'seeing',
#   'sea',
#   'for',
#   '.',
#   'at',
#   'to',
#   'of',
#   'lying',
#   'ease',
#   'Asphaltites',
#   'on',
#   'nose',
#   'innuendoes',
#   'must',
#   'storm',
#   'manfully',
#   'a',
#   'you',
#   'bed',
#   'had',
#   ...]]
